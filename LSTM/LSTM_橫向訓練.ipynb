# %%
import numpy as np
import time
from datetime import datetime
import os
import csv
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split

# %%
dataset_folder_path = "Dataset_png" # 資料集資料夾名稱
dataset_file_list = os.listdir(dataset_folder_path) # 資料集圖片名稱
dataset_file_paths = [dataset_folder_path + "/" + i for i in dataset_file_list] # 圖片完整路徑
dataset_labels = np.zeros(len(dataset_file_paths))  # 存放labels陣列

# %%
# 利用檔案名稱建立labels
for i, file_path in enumerate(dataset_file_paths):
    if 'front' in file_path:
        label = 0
    elif 'back' in file_path:
        label = 1
    elif 'left' in file_path:
        label = 2
    elif 'right' in file_path:
        label = 3
    elif 'up' in file_path:
        label = 4
    else:
        label = 5
    dataset_labels[i] = label

# 將資料集依照 7:2:1 = 訓練:驗證:測試
train_paths, val_test_paths, train_labels, val_test_labels = train_test_split(dataset_file_paths, dataset_labels, test_size = 0.3, random_state = 42)
val_paths, test_paths, val_labels, test_labels = train_test_split(val_test_paths, val_test_labels, test_size = 1/3, random_state = 42)

# 對labels進行ont-hot編碼
train_labels  = torch.tensor(train_labels)
train_labels_onehot = torch.zeros(train_labels.shape[0], 6)
train_labels_onehot.scatter_(1, train_labels.long().unsqueeze(1), 1.0)

val_labels  = torch.tensor(val_labels)
val_labels_onehot = torch.zeros(val_labels.shape[0], 6)
val_labels_onehot.scatter_(1, val_labels.long().unsqueeze(1), 1.0) 

test_labels  = torch.tensor(test_labels)
test_labels_onehot = torch.zeros(test_labels.shape[0], 6)
test_labels_onehot.scatter_(1, test_labels.long().unsqueeze(1), 1.0)

print(f"Training set size: {len(train_paths)}")
print(f"Validation set size: {len(val_paths)}")
print(f"Test set size: {len(test_paths)}")
# Out:
# Training set size: 840
# Validation set size: 240
# Test set size: 120

# %%
width = 320    # 圖片寬度
height = 240    # 圖片長度

# %%
# 進行圖片尺寸處理 尚未標準化
preprocess_without_normalize = transforms.Compose([
    transforms.Resize([height, width]),
    transforms.ToTensor(),
])

def loader_without_normalize(path):
    img = Image.open(path)
    img_tensor = preprocess_without_normalize(img)
    return img_tensor

train_imgs = torch.stack([loader_without_normalize(path) for path in train_paths], dim = 3)
val_imgs = torch.stack([loader_without_normalize(path) for path in val_paths], dim = 3)
test_imgs = torch.stack([loader_without_normalize(path) for path in test_paths], dim = 3)

print(f"train_imgs shape : {train_imgs.shape}")
print(f"val_imgs shape : {val_imgs.shape}")
print(f"test_imgs shape : {test_imgs.shape}")
# Out:
# train_imgs shape : torch.Size([1, 240, 320, 840])
# val_imgs shape : torch.Size([1, 240, 320, 240])
# test_imgs shape : torch.Size([1, 240, 320, 120])

# %%
# 計算各資料集平均值、標準差
train_mean = train_imgs.view(1, -1).mean(dim=1)
train_std = train_imgs.view(1, -1).std(dim=1)

val_mean = val_imgs.view(1, -1).mean(dim=1)
val_std = val_imgs.view(1, -1).std(dim=1)

test_mean = test_imgs.view(1, -1).mean(dim=1)
test_std = test_imgs.view(1, -1).std(dim=1)

print("訓練集平均值:", train_mean)
print("訓練集標準差:", train_std)

print("驗證集平均值:", val_mean)
print("驗證集標準差:", val_std)

print("測試集平均值:", test_mean)
print("測試集標準差:", test_std)
# Out:
# 訓練集平均值: tensor([0.2020])
# 訓練集標準差: tensor([0.2395])
# 驗證集平均值: tensor([0.1979])
# 驗證集標準差: tensor([0.2358])
# 測試集平均值: tensor([0.1872])
# 測試集標準差: tensor([0.2312])

# %%
# 設定圖片前處理、標準化
train_preprocess = transforms.Compose([
  transforms.Resize([height, width]),
  transforms.ToTensor(),
  transforms.Normalize(train_mean, train_std)
])

val_preprocess = transforms.Compose([
  transforms.Resize([height, width]),
  transforms.ToTensor(),
  transforms.Normalize(val_mean, val_std)
])

test_preprocess = transforms.Compose([
  transforms.Resize([height, width]),
  transforms.ToTensor(),
  transforms.Normalize(test_mean, test_std)
])

# 設定loader
def train_loader(path):
  img_pil = Image.open(path)
  img_tensor = train_preprocess(img_pil)
  return img_tensor

def val_loader(path):
  img_pil = Image.open(path)
  img_tensor = val_preprocess(img_pil)
  return img_tensor

def test_loader(path):
  img_pil = Image.open(path)
  img_tensor = test_preprocess(img_pil)
  return img_tensor

# %%
# 訓練資料集
class Train_set(Dataset):
  def __init__(self, loader = train_loader):
    self.images = train_paths           # 設定圖片檔案路徑列表
    self.target = train_labels_onehot   # 設定標籤列表
    self.loader = loader                # 設定圖片載入器

  def __getitem__(self, index):
    fn = self.images[index]       # 取得指定索引的圖片檔案路徑
    img = self.loader(fn)         # 使用圖片載入器載入圖片
    target = self.target[index]   # 取得指定索引的標籤
    return img, target

  def __len__(self):
    return len(self.images)       # 用於取得資料集的大小
  
# 驗證資料集
class Val_set(Dataset):
  def __init__(self, loader = val_loader):
    self.images = val_paths
    self.target = val_labels_onehot
    self.loader = loader

  def __getitem__(self, index):
    fn = self.images[index]
    img = self.loader(fn)
    target = self.target[index]
    return img, target

  def __len__(self):
    return len(self.images)
  
# 測試資料集
class Test_set(Dataset):
  def __init__(self, loader = test_loader):
    self.images = test_paths
    self.target = test_labels_onehot
    self.loader = loader
  def __getitem__(self, index):
    fn = self.images[index]
    img = self.loader(fn)
    target = self.target[index]
    return img, target

  def __len__(self):
    return len(self.images)

# %%
# 使用資料集
train_data = Train_set()
val_data = Val_set()
test_data = Test_set()

batch_size = 60
train_loader = DataLoader(train_data, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(val_data, batch_size = batch_size, shuffle = True)
test_loader = DataLoader(test_data, batch_size = batch_size, shuffle = False)

# %%
# 使用GPU訓練
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
print(f"Training on device {device}.")
# Out:
# Training on device cuda.

# %%
# LSTM 模型
class LSTM(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_layer, n_class, dropout):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim    # 隱藏層
        self.n_layer = n_layer          # 記憶層
        self.lstm = nn.LSTM(in_dim, hidden_dim, n_layer, batch_first = True, dropout = dropout) # (輸入尺寸, 隱藏層, lstm層數, 批次優先, dropout機率)
        self.linear1 = nn.Linear(hidden_dim, int(hidden_dim / 2))    # 線性層
        self.linear2 = nn.Linear(int(hidden_dim / 2), n_class)       # 全連接層
 
    def forward(self, x):             
        out, _ = self.lstm(x)                   # LSTM 前向傳播
        out = out[:, -1, :]                     # 取出序列最後一個時間輸出
        out = torch.relu(self.linear1(out))     # 線性層
        out = self.linear2(out)                 # 全連接層
        return out

# 超參數
num_epochs = 250            # 迭代次數
learning_rate = 1e-3        # 學習率
step_size = 1               # 步長
gamma = 0.9                 # 下降率
input_dim = width           # 輸入
hidden_dim = width * 2      # 隱藏層層數
n_layer = 3                 # lstm層數
n_class = 6                 # 輸出類別
dropout = 0.4               # dropout機率

model = LSTM(input_dim, hidden_dim, n_layer, n_class, dropout)     # (輸入尺寸, 隱藏層, lstm層數, 輸出類別, dropout機率)
criterion = nn.CrossEntropyLoss()                                  # 設定計算loss
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)                      # 優化器
lr = torch.optim.lr_scheduler.StepLR(optimizer, step_size = step_size, gamma = gamma)     # 學習率步階下降

# %%
# 儲存歷史資料
train_loss_history = []         # 訓練集loss
val_loss_history = []           # 驗證集loss
train_accuracy_history = []     # 訓練集準確率
val_accuracy_history = []       # 驗證集準確率
start_time = time.time()        # 訓練起始時間

for epoch in range(num_epochs):
    epoch_start_time = time.time()  # 單次迭代起始時間

    # 訓練模式
    total_train_loss = 0.0
    num_train_batches = 0
    train_correct = 0
    train_total = 0

    for (imgs, labels) in train_loader:
        imgs = imgs.reshape(-1, height, width).to(device = device)
        labels = labels.to(device = device)
        model.to(device = device)
        model.train()
        outputs = model(imgs)
        train_loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, dim = 1)
        labels = torch.argmax(labels, dim = 1)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

        # 計算總數與正確個數
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # 計算單次損失
        total_train_loss += train_loss.item()
        num_train_batches += 1
    
    # 計算此次迭代平均loss
    avg_train_loss = total_train_loss / num_train_batches 
    # 計算此次迭代平均準確率
    avg_train_accuracy = train_correct / train_total
    # 新增至歷史資料陣列
    train_loss_history.append(avg_train_loss)
    train_accuracy_history.append(avg_train_accuracy)

    # 驗證模式
    total_val_loss = 0.0
    num_val_batches = 0
    val_correct = 0
    val_total = 0

    for (imgs, labels) in val_loader:
        imgs = imgs.reshape(-1, height, width).to(device = device)
        labels = labels.to(device = device)
        model.to(device = device)
        model.eval()
        outputs = model(imgs)
        val_loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, dim = 1)
        labels = torch.argmax(labels, dim = 1)
        
        # 計算總數與正確個數
        val_total += labels.size(0)
        val_correct += (predicted == labels).sum().item()

        # 計算單次損失
        total_val_loss += val_loss.item()
        num_val_batches += 1

    # 計算此次迭代平均loss
    avg_val_loss = total_val_loss / num_val_batches
    # 計算此次迭代平均準確率
    avg_val_accuracy = val_correct / val_total
    # 新增至歷史資料陣列
    val_loss_history.append(avg_val_loss)
    val_accuracy_history.append(avg_val_accuracy)
    
    # 印出此次迭代資料
    epoch_time = time.time() - epoch_start_time
    print('Epoch: {:<2d} | Train Loss: {:.6f} | Val Loss: {:.4f} | Train Accuracy: {:.6f} | Val Accuracy: {:.4f} | Time: {:.2f} s'
          .format(epoch + 1, avg_train_loss, avg_val_loss, avg_train_accuracy, avg_val_accuracy, epoch_time))

# 此次訓練時長
total_time = time.time() - start_time
print('Training complete! Total time: {:.2f} s'.format(total_time))
# Out:
# Epoch: 1  | Train Loss: 1.637111 | Val Loss: 1.4831 | Train Accuracy: 0.290476 | Val Accuracy: 0.3833 | Time: 47.20 s
# Epoch: 2  | Train Loss: 1.370115 | Val Loss: 1.2452 | Train Accuracy: 0.411905 | Val Accuracy: 0.5083 | Time: 62.20 s
# Epoch: 3  | Train Loss: 1.212425 | Val Loss: 1.2727 | Train Accuracy: 0.483333 | Val Accuracy: 0.5000 | Time: 58.48 s
# Epoch: 4  | Train Loss: 1.182075 | Val Loss: 1.1323 | Train Accuracy: 0.483333 | Val Accuracy: 0.5417 | Time: 62.29 s
# Epoch: 5  | Train Loss: 1.015887 | Val Loss: 1.1410 | Train Accuracy: 0.564286 | Val Accuracy: 0.5375 | Time: 60.66 s
# Epoch: 6  | Train Loss: 0.958882 | Val Loss: 0.9828 | Train Accuracy: 0.584524 | Val Accuracy: 0.5833 | Time: 61.26 s
# Epoch: 7  | Train Loss: 0.885618 | Val Loss: 1.1074 | Train Accuracy: 0.605952 | Val Accuracy: 0.5625 | Time: 56.09 s
# Epoch: 8  | Train Loss: 0.884392 | Val Loss: 1.0421 | Train Accuracy: 0.601190 | Val Accuracy: 0.5667 | Time: 56.32 s
# Epoch: 9  | Train Loss: 0.860453 | Val Loss: 0.9318 | Train Accuracy: 0.596429 | Val Accuracy: 0.5667 | Time: 55.01 s
# Epoch: 10 | Train Loss: 0.744006 | Val Loss: 1.0647 | Train Accuracy: 0.672619 | Val Accuracy: 0.6417 | Time: 61.34 s
# Epoch: 11 | Train Loss: 0.826245 | Val Loss: 0.9978 | Train Accuracy: 0.655952 | Val Accuracy: 0.5875 | Time: 61.94 s
# Epoch: 12 | Train Loss: 0.795804 | Val Loss: 0.9050 | Train Accuracy: 0.629762 | Val Accuracy: 0.6208 | Time: 61.01 s
# Epoch: 13 | Train Loss: 0.699290 | Val Loss: 0.9688 | Train Accuracy: 0.698810 | Val Accuracy: 0.6417 | Time: 58.37 s
# Epoch: 14 | Train Loss: 0.675210 | Val Loss: 0.8635 | Train Accuracy: 0.710714 | Val Accuracy: 0.6500 | Time: 58.73 s
# Epoch: 15 | Train Loss: 0.634274 | Val Loss: 0.8266 | Train Accuracy: 0.713095 | Val Accuracy: 0.7083 | Time: 61.31 s
# Epoch: 16 | Train Loss: 0.546024 | Val Loss: 0.9407 | Train Accuracy: 0.761905 | Val Accuracy: 0.6708 | Time: 58.51 s
# Epoch: 17 | Train Loss: 0.640553 | Val Loss: 1.0700 | Train Accuracy: 0.736905 | Val Accuracy: 0.6333 | Time: 61.16 s
# Epoch: 18 | Train Loss: 0.603888 | Val Loss: 0.8584 | Train Accuracy: 0.745238 | Val Accuracy: 0.7083 | Time: 61.76 s
# Epoch: 19 | Train Loss: 0.517357 | Val Loss: 0.8978 | Train Accuracy: 0.775000 | Val Accuracy: 0.7042 | Time: 58.81 s
# Epoch: 20 | Train Loss: 0.486350 | Val Loss: 0.8762 | Train Accuracy: 0.784524 | Val Accuracy: 0.7125 | Time: 58.24 s
# Epoch: 21 | Train Loss: 0.504597 | Val Loss: 0.9982 | Train Accuracy: 0.782143 | Val Accuracy: 0.6625 | Time: 58.47 s
# Epoch: 22 | Train Loss: 0.556034 | Val Loss: 0.9712 | Train Accuracy: 0.763095 | Val Accuracy: 0.6833 | Time: 57.94 s
# Epoch: 23 | Train Loss: 0.544641 | Val Loss: 0.8449 | Train Accuracy: 0.780952 | Val Accuracy: 0.7083 | Time: 58.72 s
# Epoch: 24 | Train Loss: 0.476596 | Val Loss: 0.8289 | Train Accuracy: 0.778571 | Val Accuracy: 0.7083 | Time: 60.24 s
# Epoch: 25 | Train Loss: 0.402457 | Val Loss: 0.9816 | Train Accuracy: 0.822619 | Val Accuracy: 0.7333 | Time: 58.15 s
# Epoch: 26 | Train Loss: 0.410565 | Val Loss: 0.9888 | Train Accuracy: 0.825000 | Val Accuracy: 0.7000 | Time: 61.62 s
# Epoch: 27 | Train Loss: 0.430782 | Val Loss: 0.9146 | Train Accuracy: 0.797619 | Val Accuracy: 0.7208 | Time: 60.44 s
# Epoch: 28 | Train Loss: 0.433894 | Val Loss: 1.0616 | Train Accuracy: 0.798810 | Val Accuracy: 0.6583 | Time: 58.46 s
# Epoch: 29 | Train Loss: 0.467900 | Val Loss: 0.9909 | Train Accuracy: 0.817857 | Val Accuracy: 0.6958 | Time: 56.20 s
# Epoch: 30 | Train Loss: 0.415526 | Val Loss: 0.9396 | Train Accuracy: 0.827381 | Val Accuracy: 0.7375 | Time: 60.40 s
# Epoch: 31 | Train Loss: 0.349991 | Val Loss: 0.8459 | Train Accuracy: 0.841667 | Val Accuracy: 0.7667 | Time: 61.01 s
# Epoch: 32 | Train Loss: 0.372719 | Val Loss: 1.0024 | Train Accuracy: 0.854762 | Val Accuracy: 0.6708 | Time: 58.24 s
# Epoch: 33 | Train Loss: 0.394980 | Val Loss: 0.7912 | Train Accuracy: 0.819048 | Val Accuracy: 0.7458 | Time: 58.97 s
# Epoch: 34 | Train Loss: 0.357747 | Val Loss: 0.7827 | Train Accuracy: 0.840476 | Val Accuracy: 0.7708 | Time: 63.00 s
# Epoch: 35 | Train Loss: 0.333250 | Val Loss: 1.0551 | Train Accuracy: 0.857143 | Val Accuracy: 0.7208 | Time: 58.23 s
# Epoch: 36 | Train Loss: 0.393543 | Val Loss: 0.9751 | Train Accuracy: 0.834524 | Val Accuracy: 0.7458 | Time: 58.41 s
# Epoch: 37 | Train Loss: 0.341099 | Val Loss: 0.9738 | Train Accuracy: 0.857143 | Val Accuracy: 0.7250 | Time: 59.03 s
# Epoch: 38 | Train Loss: 0.483417 | Val Loss: 1.0408 | Train Accuracy: 0.827381 | Val Accuracy: 0.7083 | Time: 58.08 s
# Epoch: 39 | Train Loss: 0.581240 | Val Loss: 0.8831 | Train Accuracy: 0.780952 | Val Accuracy: 0.7333 | Time: 60.55 s
# Epoch: 40 | Train Loss: 0.528331 | Val Loss: 0.8464 | Train Accuracy: 0.789286 | Val Accuracy: 0.7125 | Time: 55.40 s
# Epoch: 41 | Train Loss: 0.482925 | Val Loss: 0.6693 | Train Accuracy: 0.775000 | Val Accuracy: 0.7333 | Time: 59.51 s
# Epoch: 42 | Train Loss: 0.376014 | Val Loss: 0.7443 | Train Accuracy: 0.854762 | Val Accuracy: 0.7583 | Time: 60.31 s
# Epoch: 43 | Train Loss: 0.397938 | Val Loss: 0.8169 | Train Accuracy: 0.829762 | Val Accuracy: 0.7583 | Time: 61.08 s
# Epoch: 44 | Train Loss: 0.358733 | Val Loss: 0.7950 | Train Accuracy: 0.853571 | Val Accuracy: 0.7375 | Time: 58.14 s
# Epoch: 45 | Train Loss: 0.320513 | Val Loss: 0.9195 | Train Accuracy: 0.875000 | Val Accuracy: 0.7500 | Time: 56.27 s
# Epoch: 46 | Train Loss: 0.310702 | Val Loss: 0.7751 | Train Accuracy: 0.878571 | Val Accuracy: 0.7625 | Time: 63.09 s
# Epoch: 47 | Train Loss: 0.292584 | Val Loss: 0.8157 | Train Accuracy: 0.871429 | Val Accuracy: 0.7375 | Time: 56.13 s
# Epoch: 48 | Train Loss: 0.277273 | Val Loss: 0.7824 | Train Accuracy: 0.880952 | Val Accuracy: 0.7875 | Time: 57.99 s
# Epoch: 49 | Train Loss: 0.316075 | Val Loss: 0.8521 | Train Accuracy: 0.867857 | Val Accuracy: 0.7625 | Time: 65.78 s
# Epoch: 50 | Train Loss: 0.338306 | Val Loss: 0.8822 | Train Accuracy: 0.844048 | Val Accuracy: 0.7125 | Time: 58.59 s
# Epoch: 51 | Train Loss: 0.327866 | Val Loss: 0.7760 | Train Accuracy: 0.855952 | Val Accuracy: 0.7333 | Time: 58.73 s
# Epoch: 52 | Train Loss: 0.295979 | Val Loss: 0.7835 | Train Accuracy: 0.890476 | Val Accuracy: 0.7583 | Time: 61.18 s
# Epoch: 53 | Train Loss: 0.304291 | Val Loss: 0.8639 | Train Accuracy: 0.884524 | Val Accuracy: 0.7750 | Time: 57.86 s
# Epoch: 54 | Train Loss: 0.395749 | Val Loss: 0.8595 | Train Accuracy: 0.854762 | Val Accuracy: 0.7292 | Time: 58.03 s
# Epoch: 55 | Train Loss: 0.380401 | Val Loss: 0.8329 | Train Accuracy: 0.842857 | Val Accuracy: 0.7750 | Time: 61.15 s
# Epoch: 56 | Train Loss: 0.404873 | Val Loss: 0.9821 | Train Accuracy: 0.840476 | Val Accuracy: 0.7333 | Time: 58.36 s
# Epoch: 57 | Train Loss: 0.511062 | Val Loss: 0.8994 | Train Accuracy: 0.794048 | Val Accuracy: 0.6917 | Time: 58.25 s
# Epoch: 58 | Train Loss: 0.486611 | Val Loss: 0.8358 | Train Accuracy: 0.790476 | Val Accuracy: 0.7250 | Time: 55.55 s
# Epoch: 59 | Train Loss: 0.381093 | Val Loss: 0.8501 | Train Accuracy: 0.848810 | Val Accuracy: 0.6958 | Time: 59.12 s
# Epoch: 60 | Train Loss: 0.357862 | Val Loss: 0.8464 | Train Accuracy: 0.858333 | Val Accuracy: 0.7583 | Time: 60.51 s
# Epoch: 61 | Train Loss: 0.332081 | Val Loss: 0.7509 | Train Accuracy: 0.855952 | Val Accuracy: 0.8042 | Time: 63.56 s
# Epoch: 62 | Train Loss: 0.316604 | Val Loss: 0.7829 | Train Accuracy: 0.876190 | Val Accuracy: 0.7542 | Time: 53.77 s
# Epoch: 63 | Train Loss: 0.404968 | Val Loss: 0.8203 | Train Accuracy: 0.844048 | Val Accuracy: 0.7750 | Time: 63.00 s
# Epoch: 64 | Train Loss: 0.366147 | Val Loss: 0.7791 | Train Accuracy: 0.865476 | Val Accuracy: 0.7583 | Time: 59.12 s
# Epoch: 65 | Train Loss: 0.348658 | Val Loss: 0.8202 | Train Accuracy: 0.852381 | Val Accuracy: 0.7458 | Time: 58.33 s
# Epoch: 66 | Train Loss: 0.322196 | Val Loss: 0.7624 | Train Accuracy: 0.861905 | Val Accuracy: 0.7625 | Time: 60.00 s
# Epoch: 67 | Train Loss: 0.350657 | Val Loss: 0.9460 | Train Accuracy: 0.845238 | Val Accuracy: 0.7333 | Time: 58.38 s
# Epoch: 68 | Train Loss: 0.296467 | Val Loss: 0.8432 | Train Accuracy: 0.876190 | Val Accuracy: 0.7458 | Time: 56.17 s
# Epoch: 69 | Train Loss: 0.257306 | Val Loss: 0.9504 | Train Accuracy: 0.884524 | Val Accuracy: 0.7500 | Time: 60.89 s
# Epoch: 70 | Train Loss: 0.323418 | Val Loss: 0.8374 | Train Accuracy: 0.869048 | Val Accuracy: 0.7250 | Time: 63.03 s
# Epoch: 71 | Train Loss: 0.316754 | Val Loss: 0.8104 | Train Accuracy: 0.871429 | Val Accuracy: 0.7500 | Time: 56.24 s
# Epoch: 72 | Train Loss: 0.354526 | Val Loss: 0.9066 | Train Accuracy: 0.864286 | Val Accuracy: 0.7000 | Time: 65.99 s
# Epoch: 73 | Train Loss: 0.349544 | Val Loss: 0.9380 | Train Accuracy: 0.848810 | Val Accuracy: 0.7000 | Time: 63.71 s
# Epoch: 74 | Train Loss: 0.345097 | Val Loss: 0.9175 | Train Accuracy: 0.845238 | Val Accuracy: 0.7292 | Time: 59.22 s
# Epoch: 75 | Train Loss: 0.283761 | Val Loss: 0.8342 | Train Accuracy: 0.884524 | Val Accuracy: 0.7375 | Time: 60.85 s
# Epoch: 76 | Train Loss: 0.275330 | Val Loss: 0.8096 | Train Accuracy: 0.882143 | Val Accuracy: 0.7875 | Time: 58.69 s
# Epoch: 77 | Train Loss: 0.259357 | Val Loss: 0.9527 | Train Accuracy: 0.898810 | Val Accuracy: 0.7667 | Time: 55.04 s
# Epoch: 78 | Train Loss: 0.252403 | Val Loss: 1.0245 | Train Accuracy: 0.898810 | Val Accuracy: 0.7500 | Time: 57.90 s
# Epoch: 79 | Train Loss: 0.270988 | Val Loss: 0.9500 | Train Accuracy: 0.888095 | Val Accuracy: 0.7500 | Time: 55.92 s
# Epoch: 80 | Train Loss: 0.248397 | Val Loss: 0.8658 | Train Accuracy: 0.890476 | Val Accuracy: 0.7958 | Time: 64.13 s
# Epoch: 81 | Train Loss: 0.222066 | Val Loss: 1.0293 | Train Accuracy: 0.908333 | Val Accuracy: 0.7333 | Time: 57.54 s
# Epoch: 82 | Train Loss: 0.220994 | Val Loss: 1.0701 | Train Accuracy: 0.914286 | Val Accuracy: 0.7917 | Time: 61.23 s
# Epoch: 83 | Train Loss: 0.504578 | Val Loss: 0.8712 | Train Accuracy: 0.832143 | Val Accuracy: 0.7708 | Time: 61.04 s
# Epoch: 84 | Train Loss: 0.313968 | Val Loss: 0.8637 | Train Accuracy: 0.866667 | Val Accuracy: 0.7750 | Time: 58.27 s
# Epoch: 85 | Train Loss: 0.267496 | Val Loss: 0.8064 | Train Accuracy: 0.886905 | Val Accuracy: 0.7875 | Time: 58.77 s
# Epoch: 86 | Train Loss: 0.312239 | Val Loss: 0.8716 | Train Accuracy: 0.884524 | Val Accuracy: 0.7667 | Time: 58.58 s
# Epoch: 87 | Train Loss: 0.293951 | Val Loss: 0.9340 | Train Accuracy: 0.880952 | Val Accuracy: 0.7417 | Time: 63.09 s
# Epoch: 88 | Train Loss: 0.274605 | Val Loss: 0.9072 | Train Accuracy: 0.909524 | Val Accuracy: 0.7792 | Time: 58.17 s
# Epoch: 89 | Train Loss: 0.245894 | Val Loss: 0.8572 | Train Accuracy: 0.902381 | Val Accuracy: 0.8042 | Time: 58.28 s
# Epoch: 90 | Train Loss: 0.251323 | Val Loss: 0.8566 | Train Accuracy: 0.901190 | Val Accuracy: 0.7917 | Time: 58.32 s
# Epoch: 91 | Train Loss: 0.295434 | Val Loss: 0.8098 | Train Accuracy: 0.879762 | Val Accuracy: 0.8167 | Time: 58.03 s
# Epoch: 92 | Train Loss: 0.231515 | Val Loss: 0.7854 | Train Accuracy: 0.909524 | Val Accuracy: 0.7792 | Time: 55.58 s
# Epoch: 93 | Train Loss: 0.234079 | Val Loss: 0.7187 | Train Accuracy: 0.900000 | Val Accuracy: 0.7917 | Time: 56.03 s
# Epoch: 94 | Train Loss: 0.216898 | Val Loss: 0.7553 | Train Accuracy: 0.916667 | Val Accuracy: 0.7958 | Time: 60.74 s
# Epoch: 95 | Train Loss: 0.220020 | Val Loss: 0.7792 | Train Accuracy: 0.911905 | Val Accuracy: 0.7917 | Time: 64.70 s
# Epoch: 96 | Train Loss: 0.175563 | Val Loss: 0.8342 | Train Accuracy: 0.939286 | Val Accuracy: 0.7792 | Time: 57.57 s
# Epoch: 97 | Train Loss: 0.161677 | Val Loss: 0.7836 | Train Accuracy: 0.936905 | Val Accuracy: 0.7750 | Time: 58.38 s
# Epoch: 98 | Train Loss: 0.203382 | Val Loss: 0.8973 | Train Accuracy: 0.923810 | Val Accuracy: 0.7583 | Time: 63.63 s
# Epoch: 99 | Train Loss: 0.231121 | Val Loss: 0.7566 | Train Accuracy: 0.914286 | Val Accuracy: 0.8083 | Time: 55.80 s
# Epoch: 100 | Train Loss: 0.207315 | Val Loss: 0.7954 | Train Accuracy: 0.917857 | Val Accuracy: 0.8000 | Time: 61.15 s
# Epoch: 101 | Train Loss: 0.230601 | Val Loss: 0.7966 | Train Accuracy: 0.898810 | Val Accuracy: 0.7917 | Time: 58.24 s
# Epoch: 102 | Train Loss: 0.262043 | Val Loss: 0.7331 | Train Accuracy: 0.883333 | Val Accuracy: 0.8042 | Time: 59.07 s
# Epoch: 103 | Train Loss: 0.208477 | Val Loss: 0.7348 | Train Accuracy: 0.911905 | Val Accuracy: 0.7958 | Time: 60.23 s
# Epoch: 104 | Train Loss: 0.214168 | Val Loss: 0.7219 | Train Accuracy: 0.917857 | Val Accuracy: 0.8125 | Time: 55.38 s
# Epoch: 105 | Train Loss: 0.171383 | Val Loss: 0.7569 | Train Accuracy: 0.941667 | Val Accuracy: 0.8083 | Time: 58.44 s
# Epoch: 106 | Train Loss: 0.190974 | Val Loss: 0.8244 | Train Accuracy: 0.920238 | Val Accuracy: 0.7875 | Time: 58.42 s
# Epoch: 107 | Train Loss: 0.190610 | Val Loss: 0.8028 | Train Accuracy: 0.932143 | Val Accuracy: 0.8042 | Time: 56.35 s
# Epoch: 108 | Train Loss: 0.209103 | Val Loss: 0.7914 | Train Accuracy: 0.913095 | Val Accuracy: 0.8000 | Time: 60.57 s
# Epoch: 109 | Train Loss: 0.173030 | Val Loss: 0.8487 | Train Accuracy: 0.922619 | Val Accuracy: 0.7917 | Time: 59.04 s
# Epoch: 110 | Train Loss: 0.214253 | Val Loss: 0.7729 | Train Accuracy: 0.911905 | Val Accuracy: 0.8458 | Time: 55.39 s
# Epoch: 111 | Train Loss: 0.183705 | Val Loss: 0.7958 | Train Accuracy: 0.933333 | Val Accuracy: 0.8292 | Time: 58.05 s
# Epoch: 112 | Train Loss: 0.159571 | Val Loss: 0.9161 | Train Accuracy: 0.945238 | Val Accuracy: 0.7875 | Time: 60.46 s
# Epoch: 113 | Train Loss: 0.149967 | Val Loss: 0.8356 | Train Accuracy: 0.944048 | Val Accuracy: 0.8292 | Time: 58.55 s
# Epoch: 114 | Train Loss: 0.140898 | Val Loss: 0.9217 | Train Accuracy: 0.941667 | Val Accuracy: 0.7917 | Time: 61.03 s
# Epoch: 115 | Train Loss: 0.142279 | Val Loss: 0.9845 | Train Accuracy: 0.946429 | Val Accuracy: 0.8083 | Time: 63.79 s
# Epoch: 116 | Train Loss: 0.213395 | Val Loss: 0.9725 | Train Accuracy: 0.909524 | Val Accuracy: 0.8000 | Time: 58.37 s
# Epoch: 117 | Train Loss: 0.204642 | Val Loss: 0.9311 | Train Accuracy: 0.907143 | Val Accuracy: 0.7875 | Time: 58.21 s
# Epoch: 118 | Train Loss: 0.177819 | Val Loss: 0.9151 | Train Accuracy: 0.923810 | Val Accuracy: 0.8042 | Time: 50.98 s
# Epoch: 119 | Train Loss: 0.172686 | Val Loss: 0.9267 | Train Accuracy: 0.929762 | Val Accuracy: 0.8042 | Time: 57.63 s
# Epoch: 120 | Train Loss: 0.166839 | Val Loss: 0.9266 | Train Accuracy: 0.936905 | Val Accuracy: 0.8083 | Time: 63.60 s
# Epoch: 121 | Train Loss: 0.170427 | Val Loss: 0.9781 | Train Accuracy: 0.927381 | Val Accuracy: 0.8042 | Time: 56.58 s
# Epoch: 122 | Train Loss: 0.170232 | Val Loss: 0.9971 | Train Accuracy: 0.932143 | Val Accuracy: 0.8042 | Time: 58.35 s
# Epoch: 123 | Train Loss: 0.156194 | Val Loss: 0.8849 | Train Accuracy: 0.942857 | Val Accuracy: 0.8167 | Time: 52.70 s
# Epoch: 124 | Train Loss: 0.142008 | Val Loss: 0.9331 | Train Accuracy: 0.953571 | Val Accuracy: 0.8250 | Time: 60.31 s
# Epoch: 125 | Train Loss: 0.138491 | Val Loss: 1.0494 | Train Accuracy: 0.954762 | Val Accuracy: 0.7917 | Time: 58.31 s
# Epoch: 126 | Train Loss: 0.196168 | Val Loss: 0.9119 | Train Accuracy: 0.934524 | Val Accuracy: 0.8208 | Time: 59.13 s
# Epoch: 127 | Train Loss: 0.236104 | Val Loss: 0.8237 | Train Accuracy: 0.919048 | Val Accuracy: 0.7917 | Time: 57.84 s
# Epoch: 128 | Train Loss: 0.253187 | Val Loss: 0.8749 | Train Accuracy: 0.907143 | Val Accuracy: 0.7875 | Time: 80.02 s
# Epoch: 129 | Train Loss: 0.185363 | Val Loss: 0.9239 | Train Accuracy: 0.934524 | Val Accuracy: 0.7750 | Time: 80.29 s
# Epoch: 130 | Train Loss: 0.241982 | Val Loss: 0.8675 | Train Accuracy: 0.919048 | Val Accuracy: 0.7750 | Time: 75.81 s
# Epoch: 131 | Train Loss: 0.181700 | Val Loss: 0.8943 | Train Accuracy: 0.929762 | Val Accuracy: 0.7875 | Time: 81.61 s
# Epoch: 132 | Train Loss: 0.199842 | Val Loss: 0.7687 | Train Accuracy: 0.919048 | Val Accuracy: 0.8208 | Time: 80.93 s
# Epoch: 133 | Train Loss: 0.282623 | Val Loss: 0.9952 | Train Accuracy: 0.890476 | Val Accuracy: 0.7750 | Time: 77.88 s
# Epoch: 134 | Train Loss: 0.407263 | Val Loss: 1.0165 | Train Accuracy: 0.836905 | Val Accuracy: 0.7417 | Time: 79.69 s
# Epoch: 135 | Train Loss: 0.323978 | Val Loss: 0.8422 | Train Accuracy: 0.884524 | Val Accuracy: 0.7708 | Time: 79.23 s
# Epoch: 136 | Train Loss: 0.231894 | Val Loss: 0.8826 | Train Accuracy: 0.914286 | Val Accuracy: 0.7792 | Time: 71.54 s
# Epoch: 137 | Train Loss: 0.223875 | Val Loss: 0.8978 | Train Accuracy: 0.923810 | Val Accuracy: 0.7750 | Time: 78.18 s
# Epoch: 138 | Train Loss: 0.229056 | Val Loss: 0.8834 | Train Accuracy: 0.922619 | Val Accuracy: 0.8000 | Time: 76.97 s
# Epoch: 139 | Train Loss: 0.232946 | Val Loss: 0.9302 | Train Accuracy: 0.913095 | Val Accuracy: 0.7875 | Time: 75.79 s
# Epoch: 140 | Train Loss: 0.178124 | Val Loss: 0.9125 | Train Accuracy: 0.933333 | Val Accuracy: 0.8125 | Time: 75.03 s
# Epoch: 141 | Train Loss: 0.169187 | Val Loss: 0.8793 | Train Accuracy: 0.923810 | Val Accuracy: 0.7917 | Time: 78.38 s
# Epoch: 142 | Train Loss: 0.218836 | Val Loss: 0.9390 | Train Accuracy: 0.915476 | Val Accuracy: 0.7458 | Time: 76.29 s
# Epoch: 143 | Train Loss: 0.204443 | Val Loss: 0.7228 | Train Accuracy: 0.926190 | Val Accuracy: 0.7958 | Time: 76.36 s
# Epoch: 144 | Train Loss: 0.173311 | Val Loss: 0.6758 | Train Accuracy: 0.932143 | Val Accuracy: 0.8042 | Time: 74.36 s
# Epoch: 145 | Train Loss: 0.169473 | Val Loss: 0.7732 | Train Accuracy: 0.932143 | Val Accuracy: 0.8083 | Time: 79.94 s
# Epoch: 146 | Train Loss: 0.198464 | Val Loss: 0.7742 | Train Accuracy: 0.919048 | Val Accuracy: 0.8167 | Time: 79.85 s
# Epoch: 147 | Train Loss: 0.217826 | Val Loss: 0.8840 | Train Accuracy: 0.920238 | Val Accuracy: 0.7875 | Time: 72.42 s
# Epoch: 148 | Train Loss: 0.187824 | Val Loss: 0.8113 | Train Accuracy: 0.933333 | Val Accuracy: 0.8083 | Time: 75.03 s
# Epoch: 149 | Train Loss: 0.217658 | Val Loss: 0.7661 | Train Accuracy: 0.926190 | Val Accuracy: 0.7917 | Time: 79.82 s
# Epoch: 150 | Train Loss: 0.230529 | Val Loss: 0.8996 | Train Accuracy: 0.916667 | Val Accuracy: 0.7833 | Time: 75.82 s
# Epoch: 151 | Train Loss: 0.184182 | Val Loss: 0.7994 | Train Accuracy: 0.926190 | Val Accuracy: 0.7750 | Time: 63.54 s
# Epoch: 152 | Train Loss: 0.185705 | Val Loss: 0.7875 | Train Accuracy: 0.932143 | Val Accuracy: 0.7958 | Time: 11.86 s
# Epoch: 153 | Train Loss: 0.203611 | Val Loss: 0.7097 | Train Accuracy: 0.921429 | Val Accuracy: 0.8250 | Time: 11.82 s
# Epoch: 154 | Train Loss: 0.195209 | Val Loss: 0.8042 | Train Accuracy: 0.914286 | Val Accuracy: 0.7833 | Time: 11.82 s
# Epoch: 155 | Train Loss: 0.155355 | Val Loss: 0.6780 | Train Accuracy: 0.938095 | Val Accuracy: 0.8292 | Time: 11.84 s
# Epoch: 156 | Train Loss: 0.162875 | Val Loss: 0.7450 | Train Accuracy: 0.940476 | Val Accuracy: 0.8042 | Time: 11.85 s
# Epoch: 157 | Train Loss: 0.157439 | Val Loss: 0.6986 | Train Accuracy: 0.941667 | Val Accuracy: 0.8208 | Time: 11.93 s
# Epoch: 158 | Train Loss: 0.179746 | Val Loss: 0.8108 | Train Accuracy: 0.933333 | Val Accuracy: 0.7625 | Time: 12.03 s
# Epoch: 159 | Train Loss: 0.144337 | Val Loss: 0.6601 | Train Accuracy: 0.947619 | Val Accuracy: 0.8375 | Time: 12.25 s
# Epoch: 160 | Train Loss: 0.110599 | Val Loss: 0.6787 | Train Accuracy: 0.960714 | Val Accuracy: 0.8208 | Time: 12.18 s
# Epoch: 161 | Train Loss: 0.125118 | Val Loss: 0.7890 | Train Accuracy: 0.942857 | Val Accuracy: 0.8167 | Time: 12.36 s
# Epoch: 162 | Train Loss: 0.174912 | Val Loss: 0.7231 | Train Accuracy: 0.940476 | Val Accuracy: 0.8167 | Time: 12.17 s
# Epoch: 163 | Train Loss: 0.228020 | Val Loss: 0.7249 | Train Accuracy: 0.909524 | Val Accuracy: 0.8375 | Time: 12.23 s
# Epoch: 164 | Train Loss: 0.215359 | Val Loss: 0.7371 | Train Accuracy: 0.919048 | Val Accuracy: 0.8250 | Time: 12.05 s
# Epoch: 165 | Train Loss: 0.189362 | Val Loss: 0.8275 | Train Accuracy: 0.936905 | Val Accuracy: 0.7958 | Time: 12.09 s
# Epoch: 166 | Train Loss: 0.211663 | Val Loss: 0.8162 | Train Accuracy: 0.923810 | Val Accuracy: 0.8042 | Time: 12.05 s
# Epoch: 167 | Train Loss: 0.176624 | Val Loss: 0.7569 | Train Accuracy: 0.930952 | Val Accuracy: 0.8208 | Time: 11.93 s
# Epoch: 168 | Train Loss: 0.162013 | Val Loss: 0.8239 | Train Accuracy: 0.933333 | Val Accuracy: 0.8042 | Time: 11.91 s
# Epoch: 169 | Train Loss: 0.157729 | Val Loss: 0.7221 | Train Accuracy: 0.942857 | Val Accuracy: 0.8208 | Time: 11.92 s
# Epoch: 170 | Train Loss: 0.241947 | Val Loss: 0.6768 | Train Accuracy: 0.905952 | Val Accuracy: 0.8167 | Time: 11.96 s
# Epoch: 171 | Train Loss: 0.165117 | Val Loss: 0.6593 | Train Accuracy: 0.936905 | Val Accuracy: 0.8208 | Time: 12.18 s
# Epoch: 172 | Train Loss: 0.144810 | Val Loss: 0.7221 | Train Accuracy: 0.951190 | Val Accuracy: 0.8375 | Time: 12.01 s
# Epoch: 173 | Train Loss: 0.131280 | Val Loss: 0.7052 | Train Accuracy: 0.951190 | Val Accuracy: 0.8333 | Time: 11.96 s
# Epoch: 174 | Train Loss: 0.128730 | Val Loss: 0.7797 | Train Accuracy: 0.952381 | Val Accuracy: 0.7917 | Time: 12.08 s
# Epoch: 175 | Train Loss: 0.139204 | Val Loss: 0.8153 | Train Accuracy: 0.944048 | Val Accuracy: 0.7708 | Time: 11.99 s
# Epoch: 176 | Train Loss: 0.161305 | Val Loss: 0.7127 | Train Accuracy: 0.929762 | Val Accuracy: 0.8000 | Time: 12.09 s
# Epoch: 177 | Train Loss: 0.124616 | Val Loss: 0.7414 | Train Accuracy: 0.951190 | Val Accuracy: 0.8167 | Time: 11.91 s
# Epoch: 178 | Train Loss: 0.115149 | Val Loss: 0.7494 | Train Accuracy: 0.955952 | Val Accuracy: 0.8167 | Time: 11.97 s
# Epoch: 179 | Train Loss: 0.087496 | Val Loss: 0.7738 | Train Accuracy: 0.970238 | Val Accuracy: 0.8208 | Time: 12.06 s
# Epoch: 180 | Train Loss: 0.100473 | Val Loss: 0.8260 | Train Accuracy: 0.958333 | Val Accuracy: 0.8167 | Time: 11.92 s
# Epoch: 181 | Train Loss: 0.133329 | Val Loss: 0.8776 | Train Accuracy: 0.950000 | Val Accuracy: 0.8125 | Time: 12.02 s
# Epoch: 182 | Train Loss: 0.202388 | Val Loss: 0.9010 | Train Accuracy: 0.914286 | Val Accuracy: 0.7917 | Time: 11.99 s
# Epoch: 183 | Train Loss: 0.204077 | Val Loss: 0.8717 | Train Accuracy: 0.913095 | Val Accuracy: 0.8125 | Time: 12.01 s
# Epoch: 184 | Train Loss: 0.168681 | Val Loss: 0.8475 | Train Accuracy: 0.938095 | Val Accuracy: 0.8042 | Time: 11.98 s
# Epoch: 185 | Train Loss: 0.130086 | Val Loss: 0.8276 | Train Accuracy: 0.946429 | Val Accuracy: 0.8167 | Time: 11.93 s
# Epoch: 186 | Train Loss: 0.111989 | Val Loss: 0.8299 | Train Accuracy: 0.958333 | Val Accuracy: 0.8125 | Time: 11.92 s
# Epoch: 187 | Train Loss: 0.100035 | Val Loss: 0.8286 | Train Accuracy: 0.960714 | Val Accuracy: 0.8167 | Time: 11.98 s
# Epoch: 188 | Train Loss: 0.093476 | Val Loss: 0.8033 | Train Accuracy: 0.961905 | Val Accuracy: 0.8250 | Time: 11.95 s
# Epoch: 189 | Train Loss: 0.085250 | Val Loss: 0.7527 | Train Accuracy: 0.969048 | Val Accuracy: 0.8375 | Time: 11.93 s
# Epoch: 190 | Train Loss: 0.119624 | Val Loss: 0.8022 | Train Accuracy: 0.951190 | Val Accuracy: 0.8333 | Time: 12.02 s
# Epoch: 191 | Train Loss: 0.135239 | Val Loss: 0.7071 | Train Accuracy: 0.955952 | Val Accuracy: 0.8417 | Time: 12.07 s
# Epoch: 192 | Train Loss: 0.140296 | Val Loss: 0.7201 | Train Accuracy: 0.942857 | Val Accuracy: 0.8292 | Time: 11.95 s
# Epoch: 193 | Train Loss: 0.149302 | Val Loss: 0.7427 | Train Accuracy: 0.941667 | Val Accuracy: 0.8167 | Time: 12.00 s
# Epoch: 194 | Train Loss: 0.240309 | Val Loss: 0.8057 | Train Accuracy: 0.904762 | Val Accuracy: 0.8042 | Time: 11.93 s
# Epoch: 195 | Train Loss: 0.205383 | Val Loss: 0.8169 | Train Accuracy: 0.913095 | Val Accuracy: 0.7958 | Time: 11.89 s
# Epoch: 196 | Train Loss: 0.210596 | Val Loss: 0.6951 | Train Accuracy: 0.916667 | Val Accuracy: 0.8292 | Time: 12.03 s
# Epoch: 197 | Train Loss: 0.175651 | Val Loss: 0.6775 | Train Accuracy: 0.930952 | Val Accuracy: 0.8208 | Time: 12.00 s
# Epoch: 198 | Train Loss: 0.168082 | Val Loss: 0.6905 | Train Accuracy: 0.929762 | Val Accuracy: 0.8292 | Time: 11.97 s
# Epoch: 199 | Train Loss: 0.154096 | Val Loss: 0.6886 | Train Accuracy: 0.938095 | Val Accuracy: 0.8417 | Time: 11.94 s
# Epoch: 200 | Train Loss: 0.215100 | Val Loss: 0.7360 | Train Accuracy: 0.923810 | Val Accuracy: 0.8333 | Time: 12.01 s
# Epoch: 201 | Train Loss: 0.212844 | Val Loss: 0.7683 | Train Accuracy: 0.925000 | Val Accuracy: 0.8250 | Time: 12.04 s
# Epoch: 202 | Train Loss: 0.137384 | Val Loss: 0.9417 | Train Accuracy: 0.950000 | Val Accuracy: 0.7750 | Time: 11.95 s
# Epoch: 203 | Train Loss: 0.176005 | Val Loss: 0.9058 | Train Accuracy: 0.936905 | Val Accuracy: 0.7958 | Time: 11.97 s
# Epoch: 204 | Train Loss: 0.171802 | Val Loss: 0.8486 | Train Accuracy: 0.939286 | Val Accuracy: 0.8125 | Time: 11.96 s
# Epoch: 205 | Train Loss: 0.164057 | Val Loss: 0.9534 | Train Accuracy: 0.930952 | Val Accuracy: 0.7958 | Time: 11.97 s
# Epoch: 206 | Train Loss: 0.132297 | Val Loss: 1.0055 | Train Accuracy: 0.947619 | Val Accuracy: 0.8000 | Time: 11.95 s
# Epoch: 207 | Train Loss: 0.147746 | Val Loss: 0.8662 | Train Accuracy: 0.951190 | Val Accuracy: 0.8250 | Time: 11.99 s
# Epoch: 208 | Train Loss: 0.154869 | Val Loss: 1.0549 | Train Accuracy: 0.944048 | Val Accuracy: 0.7708 | Time: 12.03 s
# Epoch: 209 | Train Loss: 0.195772 | Val Loss: 0.8332 | Train Accuracy: 0.928571 | Val Accuracy: 0.8208 | Time: 11.90 s
# Epoch: 210 | Train Loss: 0.163040 | Val Loss: 0.7386 | Train Accuracy: 0.940476 | Val Accuracy: 0.8250 | Time: 11.96 s
# Epoch: 211 | Train Loss: 0.130300 | Val Loss: 0.7972 | Train Accuracy: 0.951190 | Val Accuracy: 0.7833 | Time: 12.01 s
# Epoch: 212 | Train Loss: 0.187788 | Val Loss: 1.0022 | Train Accuracy: 0.930952 | Val Accuracy: 0.7792 | Time: 12.02 s
# Epoch: 213 | Train Loss: 0.180751 | Val Loss: 0.7674 | Train Accuracy: 0.926190 | Val Accuracy: 0.8042 | Time: 11.96 s
# Epoch: 214 | Train Loss: 0.170962 | Val Loss: 0.9138 | Train Accuracy: 0.925000 | Val Accuracy: 0.8042 | Time: 11.99 s
# Epoch: 215 | Train Loss: 0.167672 | Val Loss: 0.7007 | Train Accuracy: 0.939286 | Val Accuracy: 0.8292 | Time: 12.02 s
# Epoch: 216 | Train Loss: 0.150860 | Val Loss: 0.7517 | Train Accuracy: 0.945238 | Val Accuracy: 0.8083 | Time: 11.94 s
# Epoch: 217 | Train Loss: 0.149091 | Val Loss: 0.7682 | Train Accuracy: 0.952381 | Val Accuracy: 0.8333 | Time: 12.01 s
# Epoch: 218 | Train Loss: 0.112897 | Val Loss: 0.8649 | Train Accuracy: 0.963095 | Val Accuracy: 0.8250 | Time: 12.02 s
# Epoch: 219 | Train Loss: 0.104417 | Val Loss: 0.8027 | Train Accuracy: 0.966667 | Val Accuracy: 0.8333 | Time: 11.92 s
# Epoch: 220 | Train Loss: 0.092160 | Val Loss: 0.7970 | Train Accuracy: 0.964286 | Val Accuracy: 0.8458 | Time: 11.95 s
# Epoch: 221 | Train Loss: 0.181567 | Val Loss: 0.7975 | Train Accuracy: 0.951190 | Val Accuracy: 0.8167 | Time: 11.99 s
# Epoch: 222 | Train Loss: 0.232926 | Val Loss: 0.8075 | Train Accuracy: 0.917857 | Val Accuracy: 0.7958 | Time: 11.95 s
# Epoch: 223 | Train Loss: 0.137995 | Val Loss: 0.7257 | Train Accuracy: 0.950000 | Val Accuracy: 0.8333 | Time: 11.96 s
# Epoch: 224 | Train Loss: 0.123543 | Val Loss: 0.6549 | Train Accuracy: 0.960714 | Val Accuracy: 0.8583 | Time: 11.97 s
# Epoch: 225 | Train Loss: 0.104889 | Val Loss: 0.8430 | Train Accuracy: 0.961905 | Val Accuracy: 0.8083 | Time: 11.95 s
# Epoch: 226 | Train Loss: 0.072085 | Val Loss: 0.7260 | Train Accuracy: 0.975000 | Val Accuracy: 0.8375 | Time: 12.07 s
# Epoch: 227 | Train Loss: 0.078969 | Val Loss: 0.6818 | Train Accuracy: 0.975000 | Val Accuracy: 0.8542 | Time: 12.03 s
# Epoch: 228 | Train Loss: 0.057182 | Val Loss: 0.7555 | Train Accuracy: 0.980952 | Val Accuracy: 0.8292 | Time: 12.03 s
# Epoch: 229 | Train Loss: 0.079863 | Val Loss: 0.9653 | Train Accuracy: 0.971429 | Val Accuracy: 0.7875 | Time: 12.01 s
# Epoch: 230 | Train Loss: 0.074776 | Val Loss: 0.9660 | Train Accuracy: 0.961905 | Val Accuracy: 0.8333 | Time: 11.94 s
# Epoch: 231 | Train Loss: 0.173999 | Val Loss: 0.8202 | Train Accuracy: 0.938095 | Val Accuracy: 0.8292 | Time: 11.89 s
# Epoch: 232 | Train Loss: 0.203242 | Val Loss: 0.7412 | Train Accuracy: 0.928571 | Val Accuracy: 0.8333 | Time: 11.97 s
# Epoch: 233 | Train Loss: 0.236079 | Val Loss: 0.9339 | Train Accuracy: 0.923810 | Val Accuracy: 0.7958 | Time: 11.99 s
# Epoch: 234 | Train Loss: 0.313617 | Val Loss: 0.8599 | Train Accuracy: 0.884524 | Val Accuracy: 0.7625 | Time: 11.95 s
# Epoch: 235 | Train Loss: 0.279743 | Val Loss: 0.7811 | Train Accuracy: 0.880952 | Val Accuracy: 0.7833 | Time: 12.04 s
# Epoch: 236 | Train Loss: 0.251217 | Val Loss: 1.0080 | Train Accuracy: 0.891667 | Val Accuracy: 0.7625 | Time: 11.92 s
# Epoch: 237 | Train Loss: 0.382239 | Val Loss: 0.7834 | Train Accuracy: 0.841667 | Val Accuracy: 0.7833 | Time: 11.93 s
# Epoch: 238 | Train Loss: 0.385284 | Val Loss: 0.8404 | Train Accuracy: 0.863095 | Val Accuracy: 0.7792 | Time: 11.88 s
# Epoch: 239 | Train Loss: 0.408246 | Val Loss: 0.7748 | Train Accuracy: 0.845238 | Val Accuracy: 0.7958 | Time: 11.89 s
# Epoch: 240 | Train Loss: 0.282547 | Val Loss: 0.7686 | Train Accuracy: 0.898810 | Val Accuracy: 0.7792 | Time: 11.95 s
# Epoch: 241 | Train Loss: 0.204488 | Val Loss: 0.7492 | Train Accuracy: 0.914286 | Val Accuracy: 0.8125 | Time: 11.97 s
# Epoch: 242 | Train Loss: 0.171636 | Val Loss: 0.8706 | Train Accuracy: 0.933333 | Val Accuracy: 0.7875 | Time: 11.98 s
# Epoch: 243 | Train Loss: 0.144112 | Val Loss: 0.8560 | Train Accuracy: 0.948810 | Val Accuracy: 0.8375 | Time: 12.02 s
# Epoch: 244 | Train Loss: 0.121787 | Val Loss: 0.7796 | Train Accuracy: 0.954762 | Val Accuracy: 0.8375 | Time: 11.97 s
# Epoch: 245 | Train Loss: 0.109915 | Val Loss: 0.8637 | Train Accuracy: 0.958333 | Val Accuracy: 0.8167 | Time: 12.00 s
# Epoch: 246 | Train Loss: 0.097082 | Val Loss: 0.9154 | Train Accuracy: 0.957143 | Val Accuracy: 0.8208 | Time: 11.97 s
# Epoch: 247 | Train Loss: 0.146434 | Val Loss: 0.9103 | Train Accuracy: 0.941667 | Val Accuracy: 0.8417 | Time: 11.97 s
# Epoch: 248 | Train Loss: 0.093626 | Val Loss: 0.8434 | Train Accuracy: 0.959524 | Val Accuracy: 0.8333 | Time: 12.01 s
# Epoch: 249 | Train Loss: 0.109468 | Val Loss: 0.7960 | Train Accuracy: 0.958333 | Val Accuracy: 0.8333 | Time: 12.00 s
# Epoch: 250 | Train Loss: 0.076367 | Val Loss: 0.8561 | Train Accuracy: 0.969048 | Val Accuracy: 0.8375 | Time: 11.98 s
# Training complete! Total time: 10533.21 s

# %%
# 使用測試集進行準確率計算
def calculate_accuracy(model, data_loader, device):
    model.eval()  # 將模型設為評估模式
    correct = 0
    total = 0

    with torch.no_grad():
        for imgs, labels in data_loader:
            imgs = imgs.reshape(-1, height, width).to(device=device)
            labels = labels.to(device=device)
            outputs = model(imgs)
            _, predicted = torch.max(outputs, dim=1)
            labels = torch.argmax(labels, dim=1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print("Accuracy: {:.2f}".format(accuracy))

    return accuracy

test_accuracy = calculate_accuracy(model, test_loader, device)
# Out:
# Accuracy: 0.82

# %%
# 創建資料夾記錄訓練資料
current_time = datetime.now().strftime("%Y%m%d_%H%M")
folder_name = f"訓練資料/LSTM_橫向訓練_{current_time}"
os.makedirs(folder_name)
print(f"已創建資料夾: {folder_name}")
# Out:
# 已創建資料夾: 訓練資料/LSTM_橫向訓練_20240104_0013

# %%
# 儲存模型
file_path = os.path.join(folder_name, 'model.pt')
torch.save(model, file_path)

# %%
# 畫出損失趨勢圖、並儲存
plt.plot(range(1, num_epochs + 1), train_loss_history, label='Training Loss')
plt.plot(range(1, num_epochs + 1), val_loss_history, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

file_path = os.path.join(folder_name, 'loss_plot.png')
plt.savefig(file_path)
print(f"損失趨勢圖儲存至: {file_path}")

plt.show()
# Out:
# 損失趨勢圖儲存至: 訓練資料/LSTM_橫向訓練_20240104_0013\loss_plot.png

# %%
# 畫出準確率趨勢圖、並儲存
plt.plot(range(1, num_epochs + 1), train_accuracy_history, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), val_accuracy_history, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

file_path = os.path.join(folder_name, 'Accuracy_plot.png')
plt.savefig(file_path)
print(f"準確率趨勢圖儲存至: {file_path}")

plt.show()
# Out:
# 準確率趨勢圖儲存至: 訓練資料/LSTM_橫向訓練_20240104_0013\Accuracy_plot.png

# %%
# 利用csv紀錄訓練資訊
csv_file_path = os.path.join(folder_name, 'training_results.csv')
csvFile = open(csv_file_path, 'w', newline = '')
writer = csv.writer(csvFile)

writer.writerow(['Train_set size', len(train_paths)])
writer.writerow(['Val_set size', len(val_paths)])
writer.writerow(['Test_set size', len(test_paths)])
writer.writerow(['Batch size', batch_size])
writer.writerow(['Width', width])
writer.writerow(['height', height])
writer.writerow(['Num_epochs', num_epochs])
writer.writerow(['Model', f'LSTM({input_dim}, {hidden_dim}, {n_layer}, {n_class}, {dropout})'])
writer.writerow(['Optimizer', f'torch.optim.Adam(model.parameters(), lr = {learning_rate})'])
writer.writerow(['Learing rate', f'torch.optim.lr_scheduler.StepLR(optimizer, step_size = {step_size}, gamma = {gamma})'])
writer.writerow([])

writer.writerow(['Epoch', 'Train_loss', 'Val_loss', 'Train_accuracy', 'Val_accuracy'])

for i in range(1, num_epochs + 1):
    writer.writerow([
        '{:<5}'.format(i),
        '{:<10}'.format(round(train_loss_history[i-1], 5)) if train_loss_history else None,
        '{:<10}'.format(round(val_loss_history[i-1], 5)) if val_loss_history else None,
        '{:<15}'.format(round(train_accuracy_history[i-1], 5)) if train_accuracy_history else None,
        '{:<15}'.format(round(val_accuracy_history[i-1], 5)) if val_accuracy_history else None
    ])

writer.writerow([])
writer.writerow(['Test_accuracy', test_accuracy])

csvFile.close()
