# %%
import numpy as np
import time
from datetime import datetime
import os
import csv
from PIL import Image
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import DataLoader, Dataset
from sklearn.model_selection import train_test_split

# %%
dataset_folder_path = "Dataset_png" # 資料集資料夾名稱
dataset_file_list = os.listdir(dataset_folder_path) # 資料集圖片名稱
dataset_file_paths = [dataset_folder_path + "/" + i for i in dataset_file_list] # 圖片完整路徑
dataset_labels = np.zeros(len(dataset_file_paths))  # 存放labels陣列

# %%
# 利用檔案名稱建立labels
for i, file_path in enumerate(dataset_file_paths):
    if 'front' in file_path:
        label = 0
    elif 'back' in file_path:
        label = 1
    elif 'left' in file_path:
        label = 2
    elif 'right' in file_path:
        label = 3
    elif 'up' in file_path:
        label = 4
    else:
        label = 5
    dataset_labels[i] = label

# 將資料集依照 7:2:1 = 訓練:驗證:測試
train_paths, val_test_paths, train_labels, val_test_labels = train_test_split(dataset_file_paths, dataset_labels, test_size = 0.3, random_state = 42)
val_paths, test_paths, val_labels, test_labels = train_test_split(val_test_paths, val_test_labels, test_size = 1/3, random_state = 42)

# 對labels進行ont-hot編碼
train_labels  = torch.tensor(train_labels)
train_labels_onehot = torch.zeros(train_labels.shape[0], 6)
train_labels_onehot.scatter_(1, train_labels.long().unsqueeze(1), 1.0)

val_labels  = torch.tensor(val_labels)
val_labels_onehot = torch.zeros(val_labels.shape[0], 6)
val_labels_onehot.scatter_(1, val_labels.long().unsqueeze(1), 1.0) 

test_labels  = torch.tensor(test_labels)
test_labels_onehot = torch.zeros(test_labels.shape[0], 6)
test_labels_onehot.scatter_(1, test_labels.long().unsqueeze(1), 1.0)

print(f"Training set size: {len(train_paths)}")
print(f"Validation set size: {len(val_paths)}")
print(f"Test set size: {len(test_paths)}")
# Out:
# Training set size: 840
# Validation set size: 240
# Test set size: 120

# %%
width = 320    # 圖片寬度
height = 240    # 圖片長度

# %%
# 進行圖片尺寸處理 尚未標準化
preprocess_without_normalize = transforms.Compose([
    transforms.Resize([height, width]),
    transforms.ToTensor(),
])

def loader_without_normalize(path):
    img = Image.open(path)
    img_tensor = preprocess_without_normalize(img)
    return img_tensor

train_imgs = torch.stack([loader_without_normalize(path) for path in train_paths], dim = 3)
val_imgs = torch.stack([loader_without_normalize(path) for path in val_paths], dim = 3)
test_imgs = torch.stack([loader_without_normalize(path) for path in test_paths], dim = 3)

print(f"train_imgs shape : {train_imgs.shape}")
print(f"val_imgs shape : {val_imgs.shape}")
print(f"test_imgs shape : {test_imgs.shape}")
# Out:
# train_imgs shape : torch.Size([1, 240, 320, 840])
# val_imgs shape : torch.Size([1, 240, 320, 240])
# test_imgs shape : torch.Size([1, 240, 320, 120])

# %%
# 計算各資料集平均值、標準差
train_mean = train_imgs.view(1, -1).mean(dim=1)
train_std = train_imgs.view(1, -1).std(dim=1)

val_mean = val_imgs.view(1, -1).mean(dim=1)
val_std = val_imgs.view(1, -1).std(dim=1)

test_mean = test_imgs.view(1, -1).mean(dim=1)
test_std = test_imgs.view(1, -1).std(dim=1)

print("訓練集平均值:", train_mean)
print("訓練集標準差:", train_std)

print("驗證集平均值:", val_mean)
print("驗證集標準差:", val_std)

print("測試集平均值:", test_mean)
print("測試集標準差:", test_std)
# Out:
# 訓練集平均值: tensor([0.2020])
# 訓練集標準差: tensor([0.2395])
# 驗證集平均值: tensor([0.1979])
# 驗證集標準差: tensor([0.2358])
# 測試集平均值: tensor([0.1872])
# 測試集標準差: tensor([0.2312])

# %%
# 設定圖片前處理、標準化
train_preprocess = transforms.Compose([
  transforms.Resize([height, width]),
  transforms.ToTensor(),
  transforms.Normalize(train_mean, train_std)
])

val_preprocess = transforms.Compose([
  transforms.Resize([height, width]),
  transforms.ToTensor(),
  transforms.Normalize(val_mean, val_std)
])

test_preprocess = transforms.Compose([
  transforms.Resize([height, width]),
  transforms.ToTensor(),
  transforms.Normalize(test_mean, test_std)
])

# 設定loader
def train_loader(path):
  img_pil = Image.open(path)
  img_tensor = train_preprocess(img_pil)
  img_tensor = torch.transpose(img_tensor, 2, 1)
  return img_tensor

def val_loader(path):
  img_pil = Image.open(path)
  img_tensor = val_preprocess(img_pil)
  img_tensor = torch.transpose(img_tensor, 2, 1)
  return img_tensor

def test_loader(path):
  img_pil = Image.open(path)
  img_tensor = test_preprocess(img_pil)
  img_tensor = torch.transpose(img_tensor, 2, 1)
  return img_tensor

# %%
# 訓練資料集
class Train_set(Dataset):
  def __init__(self, loader = train_loader):
    self.images = train_paths           # 設定圖片檔案路徑列表
    self.target = train_labels_onehot   # 設定標籤列表
    self.loader = loader                # 設定圖片載入器

  def __getitem__(self, index):
    fn = self.images[index]       # 取得指定索引的圖片檔案路徑
    img = self.loader(fn)         # 使用圖片載入器載入圖片
    target = self.target[index]   # 取得指定索引的標籤
    return img, target

  def __len__(self):
    return len(self.images)       # 用於取得資料集的大小
  
# 驗證資料集
class Val_set(Dataset):
  def __init__(self, loader = val_loader):
    self.images = val_paths
    self.target = val_labels_onehot
    self.loader = loader

  def __getitem__(self, index):
    fn = self.images[index]
    img = self.loader(fn)
    target = self.target[index]
    return img, target

  def __len__(self):
    return len(self.images)
  
# 測試資料集
class Test_set(Dataset):
  def __init__(self, loader = test_loader):
    self.images = test_paths
    self.target = test_labels_onehot
    self.loader = loader
  def __getitem__(self, index):
    fn = self.images[index]
    img = self.loader(fn)
    target = self.target[index]
    return img, target

  def __len__(self):
    return len(self.images)

# %%
# 使用資料集
train_data = Train_set()
val_data = Val_set()
test_data = Test_set()

batch_size = 60
train_loader = DataLoader(train_data, batch_size = batch_size, shuffle = True)
val_loader = DataLoader(val_data, batch_size = batch_size, shuffle = True)
test_loader = DataLoader(test_data, batch_size = batch_size, shuffle = False)

# %%
# 使用GPU訓練
device = (torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
print(f"Training on device {device}.")
# Out:
# Training on device cuda.

# %%
# LSTM 模型
class CNN_LSTM(nn.Module):
    def __init__(self, in_dim, hidden_dim, n_layer, n_class, dropout):
        super(CNN_LSTM, self).__init__()
        # 卷積層
        self.conv1 = nn.Conv2d(1, 8, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(8, 16, kernel_size=3, padding=1)
        # LSTM
        self.hidden_dim = hidden_dim    # 隱藏層
        self.n_layer = n_layer          # 記憶層
        self.lstm = nn.LSTM(in_dim, hidden_dim, n_layer, batch_first = True, dropout = dropout) # (輸入尺寸, 隱藏層, lstm層數, 批次優先, dropout機率)
        # 線性+全連接層
        self.fc1 = nn.Linear(hidden_dim, int(hidden_dim / 2))
        self.fc2 = nn.Linear(int(hidden_dim / 2), n_class)
 
    def forward(self, x):
        #卷積層
        x = F.max_pool2d(torch.relu(self.conv1(x)), 2)
        x = F.max_pool2d(torch.relu(self.conv2(x)), 2)
        # LSTM
        x = x.reshape(-1, int(width / 4)  * 16, input_dim)
        out, _ = self.lstm(x)   # LSTM 前向傳播
        out = out[:, -1, :]     # 取出序列最後一個時間輸出
        # 線性+全連接層
        out = torch.relu(self.fc1(out))
        out = self.fc2(out)
        return out

# 超參數
num_epochs = 250            # 迭代次數
learning_rate = 1e-3        # 學習率
step_size = 1               # 步長
gamma = 0.9                 # 下降率
input_dim = int(height / 4)         # 輸入
hidden_dim = int(input_dim * 2)     # 隱藏層層數
n_layer = 3                 # lstm層數
n_class = 6                 # 輸出類別
dropout = 0.4               # dropout機率

model = CNN_LSTM(input_dim, hidden_dim, n_layer, n_class, dropout)     # (輸入尺寸, 隱藏層, lstm層數, 輸出類別, dropout機率)
criterion = nn.CrossEntropyLoss()                                  # 設定計算loss
optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate)                      # 優化器
lr = torch.optim.lr_scheduler.StepLR(optimizer, step_size = step_size, gamma = gamma)     # 學習率步階下降

# %%
# 儲存歷史資料
train_loss_history = []         # 訓練集loss
val_loss_history = []           # 驗證集loss
train_accuracy_history = []     # 訓練集準確率
val_accuracy_history = []       # 驗證集準確率
start_time = time.time()        # 訓練起始時間

for epoch in range(num_epochs):
    epoch_start_time = time.time()  # 單次迭代起始時間

    # 訓練模式
    total_train_loss = 0.0
    num_train_batches = 0
    train_correct = 0
    train_total = 0

    for (imgs, labels) in train_loader:
        imgs = imgs.to(device = device)
        labels = labels.to(device = device)
        model.to(device = device)
        model.train()
        outputs = model(imgs)
        train_loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, dim=1)
        labels = torch.argmax(labels, dim=1)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

        # 計算總數與正確個數
        train_total += labels.size(0)
        train_correct += (predicted == labels).sum().item()

        # 計算單次損失
        total_train_loss += train_loss.item()
        num_train_batches += 1
    
    # 計算此次迭代平均loss
    avg_train_loss = total_train_loss / num_train_batches 
    # 計算此次迭代平均準確率
    avg_train_accuracy = train_correct / train_total
    # 新增至歷史資料陣列
    train_loss_history.append(avg_train_loss)
    train_accuracy_history.append(avg_train_accuracy)

    # 驗證模式
    total_val_loss = 0.0
    num_val_batches = 0
    val_correct = 0
    val_total = 0

    for (imgs, labels) in val_loader:
        imgs = imgs.to(device = device)
        labels = labels.to(device = device)
        model.to(device = device)
        model.eval()
        outputs = model(imgs)
        val_loss = criterion(outputs, labels)
        _, predicted = torch.max(outputs, dim = 1)
        labels = torch.argmax(labels, dim = 1)
        
        # 計算總數與正確個數
        val_total += labels.size(0)
        val_correct += (predicted == labels).sum().item()

        # 計算單次損失
        total_val_loss += val_loss.item()
        num_val_batches += 1

    # 計算此次迭代平均loss
    avg_val_loss = total_val_loss / num_val_batches
    # 計算此次迭代平均準確率
    avg_val_accuracy = val_correct / val_total
    # 新增至歷史資料陣列
    val_loss_history.append(avg_val_loss)
    val_accuracy_history.append(avg_val_accuracy)
    
    # 印出此次迭代資料
    epoch_time = time.time() - epoch_start_time
    print('Epoch: {:<2d} | Train Loss: {:.6f} | Val Loss: {:.4f} | Train Accuracy: {:.6f} | Val Accuracy: {:.4f} | Time: {:.2f} s'
          .format(epoch + 1, avg_train_loss, avg_val_loss, avg_train_accuracy, avg_val_accuracy, epoch_time))

# 此次訓練時長
total_time = time.time() - start_time
print('Training complete! Total time: {:.2f} s'.format(total_time))
# Out:
# Epoch: 1  | Train Loss: 1.790140 | Val Loss: 1.7707 | Train Accuracy: 0.164286 | Val Accuracy: 0.1625 | Time: 22.86 s
# Epoch: 2  | Train Loss: 1.749611 | Val Loss: 1.7066 | Train Accuracy: 0.251190 | Val Accuracy: 0.2583 | Time: 17.04 s
# Epoch: 3  | Train Loss: 1.674345 | Val Loss: 1.5983 | Train Accuracy: 0.273810 | Val Accuracy: 0.3458 | Time: 27.27 s
# Epoch: 4  | Train Loss: 1.536573 | Val Loss: 1.4811 | Train Accuracy: 0.357143 | Val Accuracy: 0.3500 | Time: 28.64 s
# Epoch: 5  | Train Loss: 1.466988 | Val Loss: 1.4109 | Train Accuracy: 0.370238 | Val Accuracy: 0.4000 | Time: 30.47 s
# Epoch: 6  | Train Loss: 1.414242 | Val Loss: 1.3756 | Train Accuracy: 0.398810 | Val Accuracy: 0.4042 | Time: 30.67 s
# Epoch: 7  | Train Loss: 1.391162 | Val Loss: 1.3536 | Train Accuracy: 0.397619 | Val Accuracy: 0.4542 | Time: 27.58 s
# Epoch: 8  | Train Loss: 1.323423 | Val Loss: 1.3142 | Train Accuracy: 0.458333 | Val Accuracy: 0.4500 | Time: 31.04 s
# Epoch: 9  | Train Loss: 1.255610 | Val Loss: 1.2792 | Train Accuracy: 0.451190 | Val Accuracy: 0.4333 | Time: 30.90 s
# Epoch: 10 | Train Loss: 1.274501 | Val Loss: 1.3504 | Train Accuracy: 0.439286 | Val Accuracy: 0.4667 | Time: 27.68 s
# Epoch: 11 | Train Loss: 1.176577 | Val Loss: 1.2411 | Train Accuracy: 0.497619 | Val Accuracy: 0.5208 | Time: 30.76 s
# Epoch: 12 | Train Loss: 1.111583 | Val Loss: 1.1741 | Train Accuracy: 0.520238 | Val Accuracy: 0.5375 | Time: 30.90 s
# Epoch: 13 | Train Loss: 1.104597 | Val Loss: 1.1686 | Train Accuracy: 0.530952 | Val Accuracy: 0.5542 | Time: 27.66 s
# Epoch: 14 | Train Loss: 1.086467 | Val Loss: 1.1237 | Train Accuracy: 0.541667 | Val Accuracy: 0.5417 | Time: 33.07 s
# Epoch: 15 | Train Loss: 0.985663 | Val Loss: 1.1358 | Train Accuracy: 0.576190 | Val Accuracy: 0.6042 | Time: 31.14 s
# Epoch: 16 | Train Loss: 0.993990 | Val Loss: 1.1588 | Train Accuracy: 0.559524 | Val Accuracy: 0.5417 | Time: 30.81 s
# Epoch: 17 | Train Loss: 1.050500 | Val Loss: 1.1118 | Train Accuracy: 0.517857 | Val Accuracy: 0.5375 | Time: 27.69 s
# Epoch: 18 | Train Loss: 1.015168 | Val Loss: 1.1349 | Train Accuracy: 0.561905 | Val Accuracy: 0.5792 | Time: 33.15 s
# Epoch: 19 | Train Loss: 0.916726 | Val Loss: 1.5219 | Train Accuracy: 0.598810 | Val Accuracy: 0.5125 | Time: 31.14 s
# Epoch: 20 | Train Loss: 1.073513 | Val Loss: 1.0430 | Train Accuracy: 0.594048 | Val Accuracy: 0.5750 | Time: 30.69 s
# Epoch: 21 | Train Loss: 0.927166 | Val Loss: 0.9678 | Train Accuracy: 0.616667 | Val Accuracy: 0.6083 | Time: 27.77 s
# Epoch: 22 | Train Loss: 0.893270 | Val Loss: 1.0093 | Train Accuracy: 0.604762 | Val Accuracy: 0.6042 | Time: 33.18 s
# Epoch: 23 | Train Loss: 0.862637 | Val Loss: 0.9302 | Train Accuracy: 0.610714 | Val Accuracy: 0.6083 | Time: 31.05 s
# Epoch: 24 | Train Loss: 0.819958 | Val Loss: 0.7843 | Train Accuracy: 0.646429 | Val Accuracy: 0.6417 | Time: 30.94 s
# Epoch: 25 | Train Loss: 0.720058 | Val Loss: 0.8444 | Train Accuracy: 0.700000 | Val Accuracy: 0.6917 | Time: 27.82 s
# Epoch: 26 | Train Loss: 0.620470 | Val Loss: 0.9685 | Train Accuracy: 0.738095 | Val Accuracy: 0.6542 | Time: 30.57 s
# Epoch: 27 | Train Loss: 0.721123 | Val Loss: 0.8243 | Train Accuracy: 0.688095 | Val Accuracy: 0.6917 | Time: 30.87 s
# Epoch: 28 | Train Loss: 0.647793 | Val Loss: 0.8021 | Train Accuracy: 0.722619 | Val Accuracy: 0.7042 | Time: 27.67 s
# Epoch: 29 | Train Loss: 0.757883 | Val Loss: 0.9652 | Train Accuracy: 0.683333 | Val Accuracy: 0.6292 | Time: 30.99 s
# Epoch: 30 | Train Loss: 0.686452 | Val Loss: 0.7225 | Train Accuracy: 0.732143 | Val Accuracy: 0.7292 | Time: 30.55 s
# Epoch: 31 | Train Loss: 0.663046 | Val Loss: 0.8685 | Train Accuracy: 0.708333 | Val Accuracy: 0.6833 | Time: 27.66 s
# Epoch: 32 | Train Loss: 0.614533 | Val Loss: 0.7834 | Train Accuracy: 0.728571 | Val Accuracy: 0.7125 | Time: 33.10 s
# Epoch: 33 | Train Loss: 0.530031 | Val Loss: 0.6364 | Train Accuracy: 0.775000 | Val Accuracy: 0.7333 | Time: 32.98 s
# Epoch: 34 | Train Loss: 0.478623 | Val Loss: 0.7002 | Train Accuracy: 0.802381 | Val Accuracy: 0.7250 | Time: 30.71 s
# Epoch: 35 | Train Loss: 0.479468 | Val Loss: 0.5659 | Train Accuracy: 0.809524 | Val Accuracy: 0.7833 | Time: 25.76 s
# Epoch: 36 | Train Loss: 0.434835 | Val Loss: 0.6286 | Train Accuracy: 0.814286 | Val Accuracy: 0.7583 | Time: 30.95 s
# Epoch: 37 | Train Loss: 0.459802 | Val Loss: 0.7057 | Train Accuracy: 0.819048 | Val Accuracy: 0.7333 | Time: 30.45 s
# Epoch: 38 | Train Loss: 0.419915 | Val Loss: 0.5913 | Train Accuracy: 0.833333 | Val Accuracy: 0.7667 | Time: 27.68 s
# Epoch: 39 | Train Loss: 0.412367 | Val Loss: 0.5952 | Train Accuracy: 0.833333 | Val Accuracy: 0.7708 | Time: 32.93 s
# Epoch: 40 | Train Loss: 0.360684 | Val Loss: 0.5880 | Train Accuracy: 0.848810 | Val Accuracy: 0.7708 | Time: 30.91 s
# Epoch: 41 | Train Loss: 0.375616 | Val Loss: 0.6229 | Train Accuracy: 0.834524 | Val Accuracy: 0.7875 | Time: 30.82 s
# Epoch: 42 | Train Loss: 0.368116 | Val Loss: 0.7233 | Train Accuracy: 0.841667 | Val Accuracy: 0.7583 | Time: 27.65 s
# Epoch: 43 | Train Loss: 0.376175 | Val Loss: 0.6850 | Train Accuracy: 0.842857 | Val Accuracy: 0.7625 | Time: 32.85 s
# Epoch: 44 | Train Loss: 0.364725 | Val Loss: 0.6793 | Train Accuracy: 0.834524 | Val Accuracy: 0.7583 | Time: 33.12 s
# Epoch: 45 | Train Loss: 0.326079 | Val Loss: 0.6037 | Train Accuracy: 0.847619 | Val Accuracy: 0.7792 | Time: 30.62 s
# Epoch: 46 | Train Loss: 0.339171 | Val Loss: 0.6199 | Train Accuracy: 0.845238 | Val Accuracy: 0.7917 | Time: 31.00 s
# Epoch: 47 | Train Loss: 0.336393 | Val Loss: 0.6065 | Train Accuracy: 0.846429 | Val Accuracy: 0.7708 | Time: 27.51 s
# Epoch: 48 | Train Loss: 0.334603 | Val Loss: 0.6051 | Train Accuracy: 0.853571 | Val Accuracy: 0.7917 | Time: 32.85 s
# Epoch: 49 | Train Loss: 0.305111 | Val Loss: 0.6142 | Train Accuracy: 0.867857 | Val Accuracy: 0.7708 | Time: 30.62 s
# Epoch: 50 | Train Loss: 0.332082 | Val Loss: 0.6554 | Train Accuracy: 0.880952 | Val Accuracy: 0.8250 | Time: 25.75 s
# Epoch: 51 | Train Loss: 0.267828 | Val Loss: 0.6000 | Train Accuracy: 0.914286 | Val Accuracy: 0.8208 | Time: 32.93 s
# Epoch: 52 | Train Loss: 0.243154 | Val Loss: 0.5102 | Train Accuracy: 0.920238 | Val Accuracy: 0.8875 | Time: 31.07 s
# Epoch: 53 | Train Loss: 0.203779 | Val Loss: 0.4285 | Train Accuracy: 0.935714 | Val Accuracy: 0.8958 | Time: 30.48 s
# Epoch: 54 | Train Loss: 0.205164 | Val Loss: 0.6011 | Train Accuracy: 0.930952 | Val Accuracy: 0.8542 | Time: 27.51 s
# Epoch: 55 | Train Loss: 0.307215 | Val Loss: 0.5223 | Train Accuracy: 0.915476 | Val Accuracy: 0.8875 | Time: 30.60 s
# Epoch: 56 | Train Loss: 0.240803 | Val Loss: 0.4235 | Train Accuracy: 0.913095 | Val Accuracy: 0.9000 | Time: 30.67 s
# Epoch: 57 | Train Loss: 0.213123 | Val Loss: 0.4821 | Train Accuracy: 0.928571 | Val Accuracy: 0.8875 | Time: 27.47 s
# Epoch: 58 | Train Loss: 0.161320 | Val Loss: 0.4104 | Train Accuracy: 0.961905 | Val Accuracy: 0.8958 | Time: 30.73 s
# Epoch: 59 | Train Loss: 0.201125 | Val Loss: 0.4289 | Train Accuracy: 0.941667 | Val Accuracy: 0.9083 | Time: 30.67 s
# Epoch: 60 | Train Loss: 0.228583 | Val Loss: 0.6435 | Train Accuracy: 0.927381 | Val Accuracy: 0.8542 | Time: 27.54 s
# Epoch: 61 | Train Loss: 0.166560 | Val Loss: 0.3785 | Train Accuracy: 0.941667 | Val Accuracy: 0.9125 | Time: 32.55 s
# Epoch: 62 | Train Loss: 0.135614 | Val Loss: 0.4793 | Train Accuracy: 0.961905 | Val Accuracy: 0.9125 | Time: 30.49 s
# Epoch: 63 | Train Loss: 0.124996 | Val Loss: 0.4046 | Train Accuracy: 0.970238 | Val Accuracy: 0.9125 | Time: 25.64 s
# Epoch: 64 | Train Loss: 0.144954 | Val Loss: 0.4357 | Train Accuracy: 0.960714 | Val Accuracy: 0.9083 | Time: 33.03 s
# Epoch: 65 | Train Loss: 0.105673 | Val Loss: 0.4906 | Train Accuracy: 0.975000 | Val Accuracy: 0.9167 | Time: 32.90 s
# Epoch: 66 | Train Loss: 0.080804 | Val Loss: 0.4887 | Train Accuracy: 0.979762 | Val Accuracy: 0.9250 | Time: 30.60 s
# Epoch: 67 | Train Loss: 0.096532 | Val Loss: 0.4684 | Train Accuracy: 0.972619 | Val Accuracy: 0.8958 | Time: 30.99 s
# Epoch: 68 | Train Loss: 0.106848 | Val Loss: 0.4149 | Train Accuracy: 0.961905 | Val Accuracy: 0.9125 | Time: 27.52 s
# Epoch: 69 | Train Loss: 0.161271 | Val Loss: 0.5495 | Train Accuracy: 0.954762 | Val Accuracy: 0.8750 | Time: 30.76 s
# Epoch: 70 | Train Loss: 0.146308 | Val Loss: 0.5567 | Train Accuracy: 0.963095 | Val Accuracy: 0.8708 | Time: 30.76 s
# Epoch: 71 | Train Loss: 0.186461 | Val Loss: 0.5859 | Train Accuracy: 0.916667 | Val Accuracy: 0.7833 | Time: 27.60 s
# Epoch: 72 | Train Loss: 0.160190 | Val Loss: 0.4483 | Train Accuracy: 0.951190 | Val Accuracy: 0.9250 | Time: 30.71 s
# Epoch: 73 | Train Loss: 0.206285 | Val Loss: 0.4212 | Train Accuracy: 0.945238 | Val Accuracy: 0.8958 | Time: 30.58 s
# Epoch: 74 | Train Loss: 0.201472 | Val Loss: 0.4622 | Train Accuracy: 0.950000 | Val Accuracy: 0.9250 | Time: 27.68 s
# Epoch: 75 | Train Loss: 0.153069 | Val Loss: 0.4313 | Train Accuracy: 0.958333 | Val Accuracy: 0.9167 | Time: 32.92 s
# Epoch: 76 | Train Loss: 0.193799 | Val Loss: 0.4980 | Train Accuracy: 0.948810 | Val Accuracy: 0.9125 | Time: 30.92 s
# Epoch: 77 | Train Loss: 0.122144 | Val Loss: 0.4712 | Train Accuracy: 0.973810 | Val Accuracy: 0.8917 | Time: 30.86 s
# Epoch: 78 | Train Loss: 0.144337 | Val Loss: 0.5051 | Train Accuracy: 0.959524 | Val Accuracy: 0.8958 | Time: 27.39 s
# Epoch: 79 | Train Loss: 0.174965 | Val Loss: 0.3667 | Train Accuracy: 0.965476 | Val Accuracy: 0.9250 | Time: 32.64 s
# Epoch: 80 | Train Loss: 0.123085 | Val Loss: 0.4193 | Train Accuracy: 0.972619 | Val Accuracy: 0.9208 | Time: 28.80 s
# Epoch: 81 | Train Loss: 0.115680 | Val Loss: 0.4869 | Train Accuracy: 0.973810 | Val Accuracy: 0.9000 | Time: 27.31 s
# Epoch: 82 | Train Loss: 0.083789 | Val Loss: 0.4605 | Train Accuracy: 0.985714 | Val Accuracy: 0.9125 | Time: 32.90 s
# Epoch: 83 | Train Loss: 0.090458 | Val Loss: 0.4811 | Train Accuracy: 0.979762 | Val Accuracy: 0.8958 | Time: 30.63 s
# Epoch: 84 | Train Loss: 0.074974 | Val Loss: 0.4161 | Train Accuracy: 0.985714 | Val Accuracy: 0.9167 | Time: 25.64 s
# Epoch: 85 | Train Loss: 0.071815 | Val Loss: 0.4261 | Train Accuracy: 0.986905 | Val Accuracy: 0.9167 | Time: 30.54 s
# Epoch: 86 | Train Loss: 0.079380 | Val Loss: 0.5172 | Train Accuracy: 0.982143 | Val Accuracy: 0.9042 | Time: 30.71 s
# Epoch: 87 | Train Loss: 0.091230 | Val Loss: 0.4755 | Train Accuracy: 0.978571 | Val Accuracy: 0.9083 | Time: 27.41 s
# Epoch: 88 | Train Loss: 0.093087 | Val Loss: 0.5563 | Train Accuracy: 0.977381 | Val Accuracy: 0.8875 | Time: 33.14 s
# Epoch: 89 | Train Loss: 0.092158 | Val Loss: 0.6573 | Train Accuracy: 0.978571 | Val Accuracy: 0.8833 | Time: 32.99 s
# Epoch: 90 | Train Loss: 0.086119 | Val Loss: 0.5862 | Train Accuracy: 0.978571 | Val Accuracy: 0.8917 | Time: 30.63 s
# Epoch: 91 | Train Loss: 0.129534 | Val Loss: 0.6121 | Train Accuracy: 0.967857 | Val Accuracy: 0.8833 | Time: 25.57 s
# Epoch: 92 | Train Loss: 0.117457 | Val Loss: 0.4816 | Train Accuracy: 0.973810 | Val Accuracy: 0.9000 | Time: 32.77 s
# Epoch: 93 | Train Loss: 0.115088 | Val Loss: 0.6039 | Train Accuracy: 0.964286 | Val Accuracy: 0.8875 | Time: 30.81 s
# Epoch: 94 | Train Loss: 0.097206 | Val Loss: 0.5932 | Train Accuracy: 0.976190 | Val Accuracy: 0.9042 | Time: 30.70 s
# Epoch: 95 | Train Loss: 0.159992 | Val Loss: 0.5014 | Train Accuracy: 0.954762 | Val Accuracy: 0.9083 | Time: 27.51 s
# Epoch: 96 | Train Loss: 0.096841 | Val Loss: 0.6732 | Train Accuracy: 0.971429 | Val Accuracy: 0.8542 | Time: 32.91 s
# Epoch: 97 | Train Loss: 0.092539 | Val Loss: 0.5439 | Train Accuracy: 0.973810 | Val Accuracy: 0.9083 | Time: 30.78 s
# Epoch: 98 | Train Loss: 0.086796 | Val Loss: 0.5760 | Train Accuracy: 0.980952 | Val Accuracy: 0.9042 | Time: 30.78 s
# Epoch: 99 | Train Loss: 0.075913 | Val Loss: 0.6042 | Train Accuracy: 0.980952 | Val Accuracy: 0.9042 | Time: 27.61 s
# Epoch: 100 | Train Loss: 0.064936 | Val Loss: 0.5853 | Train Accuracy: 0.986905 | Val Accuracy: 0.9042 | Time: 33.04 s
# Epoch: 101 | Train Loss: 0.079974 | Val Loss: 0.7888 | Train Accuracy: 0.983333 | Val Accuracy: 0.8667 | Time: 32.96 s
# Epoch: 102 | Train Loss: 0.314904 | Val Loss: 0.6304 | Train Accuracy: 0.944048 | Val Accuracy: 0.9083 | Time: 30.60 s
# Epoch: 103 | Train Loss: 0.649353 | Val Loss: 0.8463 | Train Accuracy: 0.808333 | Val Accuracy: 0.7208 | Time: 25.63 s
# Epoch: 104 | Train Loss: 0.533411 | Val Loss: 0.6556 | Train Accuracy: 0.792857 | Val Accuracy: 0.7708 | Time: 30.78 s
# Epoch: 105 | Train Loss: 0.459765 | Val Loss: 0.5133 | Train Accuracy: 0.834524 | Val Accuracy: 0.8250 | Time: 30.50 s
# Epoch: 106 | Train Loss: 0.352001 | Val Loss: 0.8544 | Train Accuracy: 0.878571 | Val Accuracy: 0.7458 | Time: 27.55 s
# Epoch: 107 | Train Loss: 0.463897 | Val Loss: 0.5290 | Train Accuracy: 0.832143 | Val Accuracy: 0.8250 | Time: 32.93 s
# Epoch: 108 | Train Loss: 0.311286 | Val Loss: 0.4441 | Train Accuracy: 0.889286 | Val Accuracy: 0.8750 | Time: 31.01 s
# Epoch: 109 | Train Loss: 0.230425 | Val Loss: 0.4119 | Train Accuracy: 0.926190 | Val Accuracy: 0.8792 | Time: 30.65 s
# Epoch: 110 | Train Loss: 0.230507 | Val Loss: 0.4172 | Train Accuracy: 0.920238 | Val Accuracy: 0.8875 | Time: 27.49 s
# Epoch: 111 | Train Loss: 0.196383 | Val Loss: 0.3937 | Train Accuracy: 0.925000 | Val Accuracy: 0.8917 | Time: 32.91 s
# Epoch: 112 | Train Loss: 0.176959 | Val Loss: 0.4303 | Train Accuracy: 0.934524 | Val Accuracy: 0.8792 | Time: 31.00 s
# Epoch: 113 | Train Loss: 0.168564 | Val Loss: 0.3834 | Train Accuracy: 0.951190 | Val Accuracy: 0.9042 | Time: 30.40 s
# Epoch: 114 | Train Loss: 0.121631 | Val Loss: 0.4315 | Train Accuracy: 0.963095 | Val Accuracy: 0.9083 | Time: 27.45 s
# Epoch: 115 | Train Loss: 0.096769 | Val Loss: 0.5218 | Train Accuracy: 0.976190 | Val Accuracy: 0.8750 | Time: 31.06 s
# Epoch: 116 | Train Loss: 0.101955 | Val Loss: 0.4420 | Train Accuracy: 0.969048 | Val Accuracy: 0.9042 | Time: 30.61 s
# Epoch: 117 | Train Loss: 0.081765 | Val Loss: 0.3937 | Train Accuracy: 0.975000 | Val Accuracy: 0.9042 | Time: 27.62 s
# Epoch: 118 | Train Loss: 0.075705 | Val Loss: 0.4810 | Train Accuracy: 0.979762 | Val Accuracy: 0.9125 | Time: 33.04 s
# Epoch: 119 | Train Loss: 0.053011 | Val Loss: 0.5028 | Train Accuracy: 0.983333 | Val Accuracy: 0.8958 | Time: 30.25 s
# Epoch: 120 | Train Loss: 0.043852 | Val Loss: 0.5283 | Train Accuracy: 0.990476 | Val Accuracy: 0.8875 | Time: 25.61 s
# Epoch: 121 | Train Loss: 0.048143 | Val Loss: 0.5321 | Train Accuracy: 0.984524 | Val Accuracy: 0.8958 | Time: 32.94 s
# Epoch: 122 | Train Loss: 0.057405 | Val Loss: 0.4421 | Train Accuracy: 0.980952 | Val Accuracy: 0.9208 | Time: 30.94 s
# Epoch: 123 | Train Loss: 0.078641 | Val Loss: 0.5866 | Train Accuracy: 0.977381 | Val Accuracy: 0.8583 | Time: 30.79 s
# Epoch: 124 | Train Loss: 0.086708 | Val Loss: 0.4619 | Train Accuracy: 0.969048 | Val Accuracy: 0.9167 | Time: 27.38 s
# Epoch: 125 | Train Loss: 0.057052 | Val Loss: 0.4461 | Train Accuracy: 0.986905 | Val Accuracy: 0.9208 | Time: 30.75 s
# Epoch: 126 | Train Loss: 0.061141 | Val Loss: 0.4120 | Train Accuracy: 0.982143 | Val Accuracy: 0.9208 | Time: 30.62 s
# Epoch: 127 | Train Loss: 0.094911 | Val Loss: 0.4136 | Train Accuracy: 0.967857 | Val Accuracy: 0.9167 | Time: 27.47 s
# Epoch: 128 | Train Loss: 0.059435 | Val Loss: 0.4226 | Train Accuracy: 0.985714 | Val Accuracy: 0.9125 | Time: 33.06 s
# Epoch: 129 | Train Loss: 0.054826 | Val Loss: 0.5046 | Train Accuracy: 0.985714 | Val Accuracy: 0.9000 | Time: 32.85 s
# Epoch: 130 | Train Loss: 0.043019 | Val Loss: 0.4148 | Train Accuracy: 0.991667 | Val Accuracy: 0.9250 | Time: 30.58 s
# Epoch: 131 | Train Loss: 0.052057 | Val Loss: 0.4521 | Train Accuracy: 0.984524 | Val Accuracy: 0.9125 | Time: 25.64 s
# Epoch: 132 | Train Loss: 0.036358 | Val Loss: 0.4451 | Train Accuracy: 0.989286 | Val Accuracy: 0.9250 | Time: 32.90 s
# Epoch: 133 | Train Loss: 0.059159 | Val Loss: 0.4471 | Train Accuracy: 0.980952 | Val Accuracy: 0.9167 | Time: 32.82 s
# Epoch: 134 | Train Loss: 0.037528 | Val Loss: 0.4649 | Train Accuracy: 0.989286 | Val Accuracy: 0.9167 | Time: 30.62 s
# Epoch: 135 | Train Loss: 0.032493 | Val Loss: 0.4270 | Train Accuracy: 0.991667 | Val Accuracy: 0.9208 | Time: 30.53 s
# Epoch: 136 | Train Loss: 0.067393 | Val Loss: 0.4671 | Train Accuracy: 0.980952 | Val Accuracy: 0.9042 | Time: 27.91 s
# Epoch: 137 | Train Loss: 0.053960 | Val Loss: 0.5543 | Train Accuracy: 0.983333 | Val Accuracy: 0.8917 | Time: 32.84 s
# Epoch: 138 | Train Loss: 0.049607 | Val Loss: 0.5216 | Train Accuracy: 0.985714 | Val Accuracy: 0.9042 | Time: 30.56 s
# Epoch: 139 | Train Loss: 0.088207 | Val Loss: 0.5701 | Train Accuracy: 0.971429 | Val Accuracy: 0.8792 | Time: 25.62 s
# Epoch: 140 | Train Loss: 0.048582 | Val Loss: 0.4788 | Train Accuracy: 0.988095 | Val Accuracy: 0.9083 | Time: 30.76 s
# Epoch: 141 | Train Loss: 0.180839 | Val Loss: 0.4462 | Train Accuracy: 0.957143 | Val Accuracy: 0.9167 | Time: 30.42 s
# Epoch: 142 | Train Loss: 0.105026 | Val Loss: 0.4547 | Train Accuracy: 0.972619 | Val Accuracy: 0.9125 | Time: 27.49 s
# Epoch: 143 | Train Loss: 0.050734 | Val Loss: 0.4303 | Train Accuracy: 0.984524 | Val Accuracy: 0.9208 | Time: 31.17 s
# Epoch: 144 | Train Loss: 0.037743 | Val Loss: 0.4421 | Train Accuracy: 0.989286 | Val Accuracy: 0.9167 | Time: 30.40 s
# Epoch: 145 | Train Loss: 0.044532 | Val Loss: 0.4102 | Train Accuracy: 0.992857 | Val Accuracy: 0.9333 | Time: 27.55 s
# Epoch: 146 | Train Loss: 0.031001 | Val Loss: 0.4125 | Train Accuracy: 0.992857 | Val Accuracy: 0.9125 | Time: 30.77 s
# Epoch: 147 | Train Loss: 0.054734 | Val Loss: 0.4369 | Train Accuracy: 0.990476 | Val Accuracy: 0.9208 | Time: 30.86 s
# Epoch: 148 | Train Loss: 0.026043 | Val Loss: 0.3906 | Train Accuracy: 0.995238 | Val Accuracy: 0.9333 | Time: 27.42 s
# Epoch: 149 | Train Loss: 0.034208 | Val Loss: 0.4243 | Train Accuracy: 0.991667 | Val Accuracy: 0.9333 | Time: 30.74 s
# Epoch: 150 | Train Loss: 0.035165 | Val Loss: 0.4347 | Train Accuracy: 0.989286 | Val Accuracy: 0.9292 | Time: 30.55 s
# Epoch: 151 | Train Loss: 0.037792 | Val Loss: 0.4473 | Train Accuracy: 0.989286 | Val Accuracy: 0.9250 | Time: 27.19 s
# Epoch: 152 | Train Loss: 0.075230 | Val Loss: 0.4413 | Train Accuracy: 0.982143 | Val Accuracy: 0.9208 | Time: 32.88 s
# Epoch: 153 | Train Loss: 0.041225 | Val Loss: 0.4926 | Train Accuracy: 0.989286 | Val Accuracy: 0.9250 | Time: 30.57 s
# Epoch: 154 | Train Loss: 0.034984 | Val Loss: 0.4911 | Train Accuracy: 0.990476 | Val Accuracy: 0.9208 | Time: 25.58 s
# Epoch: 155 | Train Loss: 0.025534 | Val Loss: 0.4371 | Train Accuracy: 0.992857 | Val Accuracy: 0.9250 | Time: 32.90 s
# Epoch: 156 | Train Loss: 0.018115 | Val Loss: 0.4141 | Train Accuracy: 0.997619 | Val Accuracy: 0.9417 | Time: 30.84 s
# Epoch: 157 | Train Loss: 0.018468 | Val Loss: 0.4505 | Train Accuracy: 0.996429 | Val Accuracy: 0.9333 | Time: 30.79 s
# Epoch: 158 | Train Loss: 0.021989 | Val Loss: 0.4733 | Train Accuracy: 0.994048 | Val Accuracy: 0.9333 | Time: 27.56 s
# Epoch: 159 | Train Loss: 0.012924 | Val Loss: 0.4680 | Train Accuracy: 0.996429 | Val Accuracy: 0.9375 | Time: 30.84 s
# Epoch: 160 | Train Loss: 0.014690 | Val Loss: 0.4682 | Train Accuracy: 0.996429 | Val Accuracy: 0.9375 | Time: 30.53 s
# Epoch: 161 | Train Loss: 0.013283 | Val Loss: 0.4644 | Train Accuracy: 0.997619 | Val Accuracy: 0.9333 | Time: 27.53 s
# Epoch: 162 | Train Loss: 0.016954 | Val Loss: 0.6100 | Train Accuracy: 0.996429 | Val Accuracy: 0.9125 | Time: 33.09 s
# Epoch: 163 | Train Loss: 0.011692 | Val Loss: 0.5389 | Train Accuracy: 0.997619 | Val Accuracy: 0.9250 | Time: 31.09 s
# Epoch: 164 | Train Loss: 0.016863 | Val Loss: 0.5399 | Train Accuracy: 0.995238 | Val Accuracy: 0.9250 | Time: 30.46 s
# Epoch: 165 | Train Loss: 0.011542 | Val Loss: 0.5085 | Train Accuracy: 0.996429 | Val Accuracy: 0.9250 | Time: 27.49 s
# Epoch: 166 | Train Loss: 0.018621 | Val Loss: 0.5615 | Train Accuracy: 0.992857 | Val Accuracy: 0.9125 | Time: 30.57 s
# Epoch: 167 | Train Loss: 0.036069 | Val Loss: 0.5698 | Train Accuracy: 0.985714 | Val Accuracy: 0.9208 | Time: 30.84 s
# Epoch: 168 | Train Loss: 0.018328 | Val Loss: 0.5530 | Train Accuracy: 0.995238 | Val Accuracy: 0.9250 | Time: 27.50 s
# Epoch: 169 | Train Loss: 0.028375 | Val Loss: 0.5421 | Train Accuracy: 0.992857 | Val Accuracy: 0.9250 | Time: 32.90 s
# Epoch: 170 | Train Loss: 0.027994 | Val Loss: 0.5380 | Train Accuracy: 0.994048 | Val Accuracy: 0.9292 | Time: 31.05 s
# Epoch: 171 | Train Loss: 0.013422 | Val Loss: 0.5266 | Train Accuracy: 0.997619 | Val Accuracy: 0.9333 | Time: 30.76 s
# Epoch: 172 | Train Loss: 0.005383 | Val Loss: 0.5327 | Train Accuracy: 0.998810 | Val Accuracy: 0.9333 | Time: 27.45 s
# Epoch: 173 | Train Loss: 0.006967 | Val Loss: 0.5247 | Train Accuracy: 0.998810 | Val Accuracy: 0.9292 | Time: 32.84 s
# Epoch: 174 | Train Loss: 0.006690 | Val Loss: 0.5429 | Train Accuracy: 0.998810 | Val Accuracy: 0.9208 | Time: 32.85 s
# Epoch: 175 | Train Loss: 0.016182 | Val Loss: 0.5422 | Train Accuracy: 0.995238 | Val Accuracy: 0.9333 | Time: 30.54 s
# Epoch: 176 | Train Loss: 0.018111 | Val Loss: 0.5416 | Train Accuracy: 0.996429 | Val Accuracy: 0.9167 | Time: 25.71 s
# Epoch: 177 | Train Loss: 0.025598 | Val Loss: 0.5243 | Train Accuracy: 0.990476 | Val Accuracy: 0.9208 | Time: 32.98 s
# Epoch: 178 | Train Loss: 0.010501 | Val Loss: 0.5422 | Train Accuracy: 0.998810 | Val Accuracy: 0.9292 | Time: 30.63 s
# Epoch: 179 | Train Loss: 0.009830 | Val Loss: 0.5382 | Train Accuracy: 0.996429 | Val Accuracy: 0.9208 | Time: 30.19 s
# Epoch: 180 | Train Loss: 0.013700 | Val Loss: 0.5566 | Train Accuracy: 0.997619 | Val Accuracy: 0.9167 | Time: 28.05 s
# Epoch: 181 | Train Loss: 0.003675 | Val Loss: 0.5494 | Train Accuracy: 1.000000 | Val Accuracy: 0.9167 | Time: 30.85 s
# Epoch: 182 | Train Loss: 0.002824 | Val Loss: 0.5761 | Train Accuracy: 1.000000 | Val Accuracy: 0.9167 | Time: 30.72 s
# Epoch: 183 | Train Loss: 0.002070 | Val Loss: 0.5877 | Train Accuracy: 1.000000 | Val Accuracy: 0.9125 | Time: 27.59 s
# Epoch: 184 | Train Loss: 0.002248 | Val Loss: 0.5634 | Train Accuracy: 1.000000 | Val Accuracy: 0.9125 | Time: 33.07 s
# Epoch: 185 | Train Loss: 0.008691 | Val Loss: 0.6262 | Train Accuracy: 0.997619 | Val Accuracy: 0.9042 | Time: 31.03 s
# Epoch: 186 | Train Loss: 0.028771 | Val Loss: 0.5966 | Train Accuracy: 0.994048 | Val Accuracy: 0.9250 | Time: 30.53 s
# Epoch: 187 | Train Loss: 0.013501 | Val Loss: 0.6405 | Train Accuracy: 0.996429 | Val Accuracy: 0.9167 | Time: 27.54 s
# Epoch: 188 | Train Loss: 0.024478 | Val Loss: 0.6053 | Train Accuracy: 0.994048 | Val Accuracy: 0.9208 | Time: 30.82 s
# Epoch: 189 | Train Loss: 0.046412 | Val Loss: 0.5273 | Train Accuracy: 0.984524 | Val Accuracy: 0.9208 | Time: 30.46 s
# Epoch: 190 | Train Loss: 0.142319 | Val Loss: 0.5359 | Train Accuracy: 0.967857 | Val Accuracy: 0.8958 | Time: 27.60 s
# Epoch: 191 | Train Loss: 0.148453 | Val Loss: 0.4576 | Train Accuracy: 0.964286 | Val Accuracy: 0.8917 | Time: 33.10 s
# Epoch: 192 | Train Loss: 0.093651 | Val Loss: 0.3547 | Train Accuracy: 0.970238 | Val Accuracy: 0.9167 | Time: 32.85 s
# Epoch: 193 | Train Loss: 0.270409 | Val Loss: 0.5022 | Train Accuracy: 0.908333 | Val Accuracy: 0.8750 | Time: 30.66 s
# Epoch: 194 | Train Loss: 0.207048 | Val Loss: 0.5515 | Train Accuracy: 0.939286 | Val Accuracy: 0.8750 | Time: 25.73 s
# Epoch: 195 | Train Loss: 0.082233 | Val Loss: 0.3925 | Train Accuracy: 0.978571 | Val Accuracy: 0.9083 | Time: 30.83 s
# Epoch: 196 | Train Loss: 0.053668 | Val Loss: 0.4007 | Train Accuracy: 0.980952 | Val Accuracy: 0.9167 | Time: 30.47 s
# Epoch: 197 | Train Loss: 0.103710 | Val Loss: 0.4935 | Train Accuracy: 0.967857 | Val Accuracy: 0.8958 | Time: 27.56 s
# Epoch: 198 | Train Loss: 0.116750 | Val Loss: 0.5123 | Train Accuracy: 0.965476 | Val Accuracy: 0.9000 | Time: 30.57 s
# Epoch: 199 | Train Loss: 0.040048 | Val Loss: 0.5114 | Train Accuracy: 0.986905 | Val Accuracy: 0.9042 | Time: 30.44 s
# Epoch: 200 | Train Loss: 0.034205 | Val Loss: 0.4849 | Train Accuracy: 0.990476 | Val Accuracy: 0.9250 | Time: 27.82 s
# Epoch: 201 | Train Loss: 0.034659 | Val Loss: 0.4665 | Train Accuracy: 0.994048 | Val Accuracy: 0.9250 | Time: 32.94 s
# Epoch: 202 | Train Loss: 0.027125 | Val Loss: 0.3999 | Train Accuracy: 0.992857 | Val Accuracy: 0.9208 | Time: 30.93 s
# Epoch: 203 | Train Loss: 0.028393 | Val Loss: 0.4357 | Train Accuracy: 0.992857 | Val Accuracy: 0.9208 | Time: 30.69 s
# Epoch: 204 | Train Loss: 0.015527 | Val Loss: 0.4620 | Train Accuracy: 0.997619 | Val Accuracy: 0.9208 | Time: 27.63 s
# Epoch: 205 | Train Loss: 0.010737 | Val Loss: 0.4779 | Train Accuracy: 0.998810 | Val Accuracy: 0.9208 | Time: 30.48 s
# Epoch: 206 | Train Loss: 0.006644 | Val Loss: 0.4554 | Train Accuracy: 0.998810 | Val Accuracy: 0.9167 | Time: 30.71 s
# Epoch: 207 | Train Loss: 0.009936 | Val Loss: 0.4590 | Train Accuracy: 0.998810 | Val Accuracy: 0.9167 | Time: 27.51 s
# Epoch: 208 | Train Loss: 0.028945 | Val Loss: 0.4892 | Train Accuracy: 0.996429 | Val Accuracy: 0.9083 | Time: 30.84 s
# Epoch: 209 | Train Loss: 0.042697 | Val Loss: 0.4076 | Train Accuracy: 0.989286 | Val Accuracy: 0.9167 | Time: 30.57 s
# Epoch: 210 | Train Loss: 0.021578 | Val Loss: 0.4242 | Train Accuracy: 0.994048 | Val Accuracy: 0.9208 | Time: 27.87 s
# Epoch: 211 | Train Loss: 0.015628 | Val Loss: 0.4717 | Train Accuracy: 0.995238 | Val Accuracy: 0.9250 | Time: 30.71 s
# Epoch: 212 | Train Loss: 0.009419 | Val Loss: 0.4920 | Train Accuracy: 0.997619 | Val Accuracy: 0.9250 | Time: 30.28 s
# Epoch: 213 | Train Loss: 0.009877 | Val Loss: 0.4897 | Train Accuracy: 0.997619 | Val Accuracy: 0.9167 | Time: 27.51 s
# Epoch: 214 | Train Loss: 0.007743 | Val Loss: 0.4945 | Train Accuracy: 0.997619 | Val Accuracy: 0.9167 | Time: 30.91 s
# Epoch: 215 | Train Loss: 0.008017 | Val Loss: 0.4782 | Train Accuracy: 0.997619 | Val Accuracy: 0.9250 | Time: 30.71 s
# Epoch: 216 | Train Loss: 0.014935 | Val Loss: 0.5627 | Train Accuracy: 0.996429 | Val Accuracy: 0.8958 | Time: 27.42 s
# Epoch: 217 | Train Loss: 0.032723 | Val Loss: 0.4788 | Train Accuracy: 0.994048 | Val Accuracy: 0.9167 | Time: 30.61 s
# Epoch: 218 | Train Loss: 0.017656 | Val Loss: 0.4713 | Train Accuracy: 0.995238 | Val Accuracy: 0.9208 | Time: 30.45 s
# Epoch: 219 | Train Loss: 0.030011 | Val Loss: 0.4890 | Train Accuracy: 0.989286 | Val Accuracy: 0.9125 | Time: 27.43 s
# Epoch: 220 | Train Loss: 0.043272 | Val Loss: 0.5856 | Train Accuracy: 0.988095 | Val Accuracy: 0.9083 | Time: 30.24 s
# Epoch: 221 | Train Loss: 0.030554 | Val Loss: 0.5414 | Train Accuracy: 0.989286 | Val Accuracy: 0.9208 | Time: 25.73 s
# Epoch: 222 | Train Loss: 0.030837 | Val Loss: 0.5059 | Train Accuracy: 0.986905 | Val Accuracy: 0.9000 | Time: 30.85 s
# Epoch: 223 | Train Loss: 0.065916 | Val Loss: 0.6347 | Train Accuracy: 0.982143 | Val Accuracy: 0.9083 | Time: 30.47 s
# Epoch: 224 | Train Loss: 0.029196 | Val Loss: 0.6697 | Train Accuracy: 0.989286 | Val Accuracy: 0.9167 | Time: 27.54 s
# Epoch: 225 | Train Loss: 0.017624 | Val Loss: 0.5045 | Train Accuracy: 0.995238 | Val Accuracy: 0.9292 | Time: 33.02 s
# Epoch: 226 | Train Loss: 0.031803 | Val Loss: 0.5509 | Train Accuracy: 0.990476 | Val Accuracy: 0.9250 | Time: 32.94 s
# Epoch: 227 | Train Loss: 0.021890 | Val Loss: 0.6185 | Train Accuracy: 0.996429 | Val Accuracy: 0.9042 | Time: 28.73 s
# Epoch: 228 | Train Loss: 0.016182 | Val Loss: 0.5387 | Train Accuracy: 0.994048 | Val Accuracy: 0.9208 | Time: 27.44 s
# Epoch: 229 | Train Loss: 0.019347 | Val Loss: 0.5559 | Train Accuracy: 0.992857 | Val Accuracy: 0.9125 | Time: 32.95 s
# Epoch: 230 | Train Loss: 0.006053 | Val Loss: 0.6463 | Train Accuracy: 0.997619 | Val Accuracy: 0.8958 | Time: 30.94 s
# Epoch: 231 | Train Loss: 0.003281 | Val Loss: 0.5534 | Train Accuracy: 1.000000 | Val Accuracy: 0.9208 | Time: 30.81 s
# Epoch: 232 | Train Loss: 0.037335 | Val Loss: 0.6606 | Train Accuracy: 0.988095 | Val Accuracy: 0.8958 | Time: 27.62 s
# Epoch: 233 | Train Loss: 0.064660 | Val Loss: 0.5821 | Train Accuracy: 0.984524 | Val Accuracy: 0.9125 | Time: 30.84 s
# Epoch: 234 | Train Loss: 0.060187 | Val Loss: 0.4565 | Train Accuracy: 0.985714 | Val Accuracy: 0.9125 | Time: 30.54 s
# Epoch: 235 | Train Loss: 0.031980 | Val Loss: 0.5054 | Train Accuracy: 0.986905 | Val Accuracy: 0.9292 | Time: 27.57 s
# Epoch: 236 | Train Loss: 0.030335 | Val Loss: 0.6405 | Train Accuracy: 0.990476 | Val Accuracy: 0.8917 | Time: 30.54 s
# Epoch: 237 | Train Loss: 0.028569 | Val Loss: 0.5218 | Train Accuracy: 0.994048 | Val Accuracy: 0.9000 | Time: 30.75 s
# Epoch: 238 | Train Loss: 0.011067 | Val Loss: 0.4991 | Train Accuracy: 0.996429 | Val Accuracy: 0.9125 | Time: 27.60 s
# Epoch: 239 | Train Loss: 0.011797 | Val Loss: 0.4867 | Train Accuracy: 0.995238 | Val Accuracy: 0.9042 | Time: 30.76 s
# Epoch: 240 | Train Loss: 0.014272 | Val Loss: 0.5552 | Train Accuracy: 0.996429 | Val Accuracy: 0.9083 | Time: 30.61 s
# Epoch: 241 | Train Loss: 0.006513 | Val Loss: 0.5171 | Train Accuracy: 0.998810 | Val Accuracy: 0.9083 | Time: 27.49 s
# Epoch: 242 | Train Loss: 0.008965 | Val Loss: 0.4520 | Train Accuracy: 0.998810 | Val Accuracy: 0.9208 | Time: 32.95 s
# Epoch: 243 | Train Loss: 0.005842 | Val Loss: 0.4504 | Train Accuracy: 0.998810 | Val Accuracy: 0.9208 | Time: 31.03 s
# Epoch: 244 | Train Loss: 0.003085 | Val Loss: 0.4615 | Train Accuracy: 1.000000 | Val Accuracy: 0.9208 | Time: 30.58 s
# Epoch: 245 | Train Loss: 0.002347 | Val Loss: 0.4910 | Train Accuracy: 1.000000 | Val Accuracy: 0.9250 | Time: 27.57 s
# Epoch: 246 | Train Loss: 0.001874 | Val Loss: 0.5380 | Train Accuracy: 1.000000 | Val Accuracy: 0.9250 | Time: 32.57 s
# Epoch: 247 | Train Loss: 0.001365 | Val Loss: 0.5325 | Train Accuracy: 1.000000 | Val Accuracy: 0.9250 | Time: 30.65 s
# Epoch: 248 | Train Loss: 0.001355 | Val Loss: 0.4646 | Train Accuracy: 1.000000 | Val Accuracy: 0.9250 | Time: 25.67 s
# Epoch: 249 | Train Loss: 0.003961 | Val Loss: 0.4787 | Train Accuracy: 0.998810 | Val Accuracy: 0.9167 | Time: 30.93 s
# Epoch: 250 | Train Loss: 0.008795 | Val Loss: 0.4712 | Train Accuracy: 0.997619 | Val Accuracy: 0.9375 | Time: 30.64 s
# Training complete! Total time: 7502.06 s

# %%
# 使用測試集進行準確率計算
def calculate_accuracy(model, data_loader, device):
    model.eval()  # 將模型設為評估模式
    correct = 0
    total = 0

    with torch.no_grad():
        for imgs, labels in data_loader:
            imgs = imgs.to(device = device)
            labels = labels.to(device=device)
            outputs = model(imgs)
            _, predicted = torch.max(outputs, dim=1)
            labels = torch.argmax(labels, dim=1)

            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = correct / total
    print("Accuracy: {:.2f}".format(accuracy))
    
    return accuracy

test_accuracy = calculate_accuracy(model, test_loader, device)
# Out:
# Accuracy: 0.96

# %%
# 創建資料夾記錄訓練資料
current_time = datetime.now().strftime("%Y%m%d_%H%M")
folder_name = f"訓練資料/CNN+LSTM_直向訓練_{current_time}"
os.makedirs(folder_name)
print(f"已創建資料夾: {folder_name}")
# Out:
# 已創建資料夾: 訓練資料/CNN+LSTM_直向訓練_20240103_2322

# %%
# 儲存模型
file_path = os.path.join(folder_name, 'model.pt')
torch.save(model, file_path)

# %%
# 畫出損失趨勢圖、並儲存
plt.plot(range(1, num_epochs + 1), train_loss_history, label='Training Loss')
plt.plot(range(1, num_epochs + 1), val_loss_history, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')

file_path = os.path.join(folder_name, 'loss_plot.png')
plt.savefig(file_path)
print(f"損失趨勢圖儲存至: {file_path}")

plt.show()
# Out:
# 損失趨勢圖儲存至: 訓練資料/CNN+LSTM_直向訓練_20240103_2322\loss_plot.png

# %%
# 畫出準確率趨勢圖、並儲存
plt.plot(range(1, num_epochs + 1), train_accuracy_history, label='Training Accuracy')
plt.plot(range(1, num_epochs + 1), val_accuracy_history, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Training and Validation Accuracy')

file_path = os.path.join(folder_name, 'Accuracy_plot.png')
plt.savefig(file_path)
print(f"準確率趨勢圖儲存至: {file_path}")

plt.show()
# Out:
# 準確率趨勢圖儲存至: 訓練資料/CNN+LSTM_直向訓練_20240103_2322\Accuracy_plot.png

# %%
# 利用csv紀錄訓練資訊
csv_file_path = os.path.join(folder_name, 'training_results.csv')
csvFile = open(csv_file_path, 'w', newline = '')
writer = csv.writer(csvFile)

writer.writerow(['Train_set size', len(train_paths)])
writer.writerow(['Val_set size', len(val_paths)])
writer.writerow(['Test_set size', len(test_paths)])
writer.writerow(['Batch size', batch_size])
writer.writerow(['Width', width])
writer.writerow(['Length', height])
writer.writerow(['Num_epochs', num_epochs])
writer.writerow(['Model', f'LSTM({input_dim}, {hidden_dim}, {n_layer}, {n_class}, {dropout})'])
writer.writerow(['Optimizer', f'torch.optim.Adam(model.parameters(), lr = {learning_rate})'])
writer.writerow(['Learing rate', f'torch.optim.lr_scheduler.StepLR(optimizer, step_size = {step_size}, gamma = {gamma})'])
writer.writerow([])

writer.writerow(['Epoch', 'Train_loss', 'Val_loss', 'Train_accuracy', 'Val_accuracy'])

for i in range(1, num_epochs + 1):
    writer.writerow([
        '{:<5}'.format(i),
        '{:<10}'.format(round(train_loss_history[i-1], 5)) if train_loss_history else None,
        '{:<10}'.format(round(val_loss_history[i-1], 5)) if val_loss_history else None,
        '{:<15}'.format(round(train_accuracy_history[i-1], 5)) if train_accuracy_history else None,
        '{:<15}'.format(round(val_accuracy_history[i-1], 5)) if val_accuracy_history else None
    ])

writer.writerow([])
writer.writerow(['Test_accuracy', test_accuracy])

csvFile.close()
